# %% [markdown]
# #### Insurance Claims- Fraud Detection
# <b>By Sajad Manaf<b>

# %% [markdown]
# <b>Problem Statement:<b>
#
# Business case:
#
# Insurance fraud is a huge problem in the industry. It's difficult to identify fraud claims. Machine Learning is in a unique position to help the Auto Insurance industry with this problem.
#
# In this project, you are provided a dataset which has the details of the insurance policy along with the customer details. It also has the details of the accident on the basis of which the claims have been made.
#
# In this example, you will be working with some auto insurance data to demonstrate how you can create a predictive model that predicts if an insurance claim is fraudulent or not.
#
# Dataset Link -  https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv

# %%
import pandas as pd # data wrangling 
import numpy as np # Basic computations
import seaborn as sns # Visualization 
import matplotlib.pyplot as plt # plot package
# %matplotlib inline
import warnings # Filter warnings
warnings.filterwarnings('ignore')

# %%
# importing insurance fraud data set

# Importing Insurance Claims dataset Csv file using pandas
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 1000
# No of Columns: 40
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    25-01-2015  Single Vehicle Collision   Side Collision      Major Damage
# 1    21-01-2015             Vehicle Theft                ?      Minor Damage
# 2    22-02-2015   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    10-01-2015  Single Vehicle Collision  Front Collision      Major Damage
# 4    17-02-2015             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
# Group of Features in Datatype groups

df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['months_as_customer', 'age', 'policy_number', 'policy_deductable', 'umbrella_limit', 'insured_zip', 'capital-gains', 'capital-loss', 'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 'total_claim_amount', 'injury_claim', 'property_claim', 'vehicle_claim', 'auto_year'], float64: ['policy_annual_premium', '_c39'], object: ['policy_bind_date', 'policy_state', 'policy_csl', 'insured_sex', 'insured_education_level', 'insured_occupation', 'insured_hobbies', 'insured_relationship', 'incident_date', 'incident_type', 'collision_type', 'incident_severity', 'authorities_contacted', 'incident_state', 'incident_city', 'incident_location', 'property_damage', 'police_report_available', 'auto_make', 'auto_model', 'fraud_reported']}

# %% [markdown]
# #### Duplicate Checks

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - No Duplicate Records

# %% [markdown]
# #### Whitesspaces or Special Characters Check

# %%
df.isin([' ','NA','-']).sum().any()
# Out:
# False

# %% [markdown]
# - No Special Characters or whitespaces

# %%
df.isin(['?']).sum().any()
# Out:
# True

# %%
df.isin(['?']).sum()
# Out:
# months_as_customer               0
# age                              0
# policy_number                    0
# policy_bind_date                 0
# policy_state                     0
# policy_csl                       0
# policy_deductable                0
# policy_annual_premium            0
# umbrella_limit                   0
# insured_zip                      0
# insured_sex                      0
# insured_education_level          0
# insured_occupation               0
# insured_hobbies                  0
# insured_relationship             0
# capital-gains                    0
# capital-loss                     0
# incident_date                    0
# incident_type                    0
# collision_type                 178
# incident_severity                0
# authorities_contacted            0
# incident_state                   0
# incident_city                    0
# incident_location                0
# incident_hour_of_the_day         0
# number_of_vehicles_involved      0
# property_damage                360
# bodily_injuries                  0
# witnesses                        0
# police_report_available        343
# total_claim_amount               0
# injury_claim                     0
# property_claim                   0
# vehicle_claim                    0
# auto_make                        0
# auto_model                       0
# auto_year                        0
# fraud_reported                   0
# _c39                             0
# dtype: int64

# %%
#### Replace '?' with NaN

df=df.replace('?',np.NaN)

# %% [markdown]
# #### Missing Val Check

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                              Missing Values  % Missing data
# _c39                                   1000           100.0
# property_damage                         360            36.0
# police_report_available                 343            34.3
# collision_type                          178            17.8
# bodily_injuries                           0             0.0
# incident_state                            0             0.0
# incident_city                             0             0.0
# incident_location                         0             0.0
# incident_hour_of_the_day                  0             0.0
# number_of_vehicles_involved               0             0.0
# fraud_reported                            0             0.0
# auto_year                                 0             0.0
# auto_model                                0             0.0
# authorities_contacted                     0             0.0
# total_claim_amount                        0             0.0
# injury_claim                              0             0.0
# property_claim                            0             0.0
# vehicle_claim                             0             0.0
# auto_make                                 0             0.0
# witnesses                                 0             0.0
# months_as_customer                        0             0.0
# age                                       0             0.0
# insured_zip                               0             0.0
# policy_number                             0             0.0
# policy_bind_date                          0             0.0
# policy_state                              0             0.0
# policy_csl                                0             0.0
# policy_deductable                         0             0.0
# policy_annual_premium                     0             0.0
# umbrella_limit                            0             0.0
# insured_sex                               0             0.0
# incident_type                             0             0.0
# insured_education_level                   0             0.0
# insured_occupation                        0             0.0
# insured_hobbies                           0             0.0
# insured_relationship                      0             0.0
# capital-gains                             0             0.0
# capital-loss                              0             0.0
# incident_date                             0             0.0
# incident_severity                         0             0.0

# %% [markdown]
# - _c39 is an irrelevant feature with 100% data are missing, we will drop this feature
# - property_damage, police_report_available, collision_type features are having missing values with pct's 36.0, 34.3, 17.8

# %%
df.nunique()
# Out:
# months_as_customer              391
# age                              46
# policy_number                  1000
# policy_bind_date                951
# policy_state                      3
# policy_csl                        3
# policy_deductable                 3
# policy_annual_premium           991
# umbrella_limit                   11
# insured_zip                     995
# insured_sex                       2
# insured_education_level           7
# insured_occupation               14
# insured_hobbies                  20
# insured_relationship              6
# capital-gains                   338
# capital-loss                    354
# incident_date                    60
# incident_type                     4
# collision_type                    3
# incident_severity                 4
# authorities_contacted             5
# incident_state                    7
# incident_city                     7
# incident_location              1000
# incident_hour_of_the_day         24
# number_of_vehicles_involved       4
# property_damage                   2
# bodily_injuries                   3
# witnesses                         4
# police_report_available           2
# total_claim_amount              763
# injury_claim                    638
# property_claim                  626
# vehicle_claim                   726
# auto_make                        14
# auto_model                       39
# auto_year                        21
# fraud_reported                    2
# _c39                              0
# dtype: int64

# %% [markdown]
# - All the missing value features are categorical in nature, so they can be imputed with Mod method

# %% [markdown]
# #### Data Imputation

# %%
df['property_damage'].fillna(df['property_damage'].mode()[0],inplace=True)
df['police_report_available'].fillna(df['police_report_available'].mode()[0],inplace=True)
df['collision_type'].fillna(df['collision_type'].mode()[0],inplace=True)

# %% [markdown]
# #### Removing irrelevant Features
# - '_c39','incident_location','insured_zip','policy_number' are irrelevant and wiull not contribute to the model

# %%
df.drop(['_c39','incident_location','insured_zip','policy_number'],axis=1,inplace=True)

# %% [markdown]
# #### Missing Value Check After the Imputing Values

# %%
sns.heatmap(df.isnull(),cmap="Greens")
plt.show()

# %% [markdown]
# - No Missing Values

# %% [markdown]
# - policy_csl features is marked as an Object Data Type-but while analysis it is found that this is due to two neumeric values are concatinated with '/'.
# - Let's split the feature in to two CSL_Personal ans CSL_Accidental.

# %%
# Spliting and deviding policy_csl at '/'
df['CSL_Personal']=df.policy_csl.str.split('/',expand=True)[0]
df['CSL_Accidental']=df.policy_csl.str.split('/',expand=True)[1]

# %%
# Now we can drop policy_csl column 
df.drop("policy_csl",axis=1,inplace=True)

# %% [markdown]
# - Two date Features, policy_bind_date, incident_date are marked as Objects, which are needs to be converetd to Date first and later to DD,MM,YYYY split

# %%
# Converting Date columns from object type into datetime data type
df['policy_bind_date']=pd.to_datetime(df['policy_bind_date'])
df['incident_date']=pd.to_datetime(df['incident_date'])

# %%
# Extracting Day, Month and Year column from policy_bind_date
df['policy_bind_day'] = df['policy_bind_date'].dt.day
df['policy_bind_month'] = df['policy_bind_date'].dt.month
df['policy_bind_year'] = df['policy_bind_date'].dt.year

# Extracting Day, Month and Year column from incident_date
df['incident_day'] = df['incident_date'].dt.day
df['incident_month'] = df['incident_date'].dt.month
df['incident_year'] = df['incident_date'].dt.year

# %%
# Since Extraction is done now we can Drop policy_bind_date and incident_date columns
df.drop(['policy_bind_date','incident_date'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_state                 1000 non-null   object
#  3   policy_deductable            1000 non-null   int64
#  4   policy_annual_premium        1000 non-null   float64
#  5   umbrella_limit               1000 non-null   int64
#  6   insured_sex                  1000 non-null   object
#  7   insured_education_level      1000 non-null   object
#  8   insured_occupation           1000 non-null   object
#  9   insured_hobbies              1000 non-null   object
#  10  insured_relationship         1000 non-null   object
#  11  capital-gains                1000 non-null   int64
#  12  capital-loss                 1000 non-null   int64
#  13  incident_type                1000 non-null   object
#  14  collision_type               1000 non-null   object
#  15  incident_severity            1000 non-null   object
#  16  authorities_contacted        1000 non-null   object
#  17  incident_state               1000 non-null   object
#  18  incident_city                1000 non-null   object
#  19  incident_hour_of_the_day     1000 non-null   int64
#  20  number_of_vehicles_involved  1000 non-null   int64
#  21  property_damage              1000 non-null   object
#  22  bodily_injuries              1000 non-null   int64
#  23  witnesses                    1000 non-null   int64
#  24  police_report_available      1000 non-null   object
#  25  total_claim_amount           1000 non-null   int64
#  26  injury_claim                 1000 non-null   int64
#  27  property_claim               1000 non-null   int64
#  28  vehicle_claim                1000 non-null   int64
#  29  auto_make                    1000 non-null   object
#  30  auto_model                   1000 non-null   object
#  31  auto_year                    1000 non-null   int64
#  32  fraud_reported               1000 non-null   object
#  33  CSL_Personal                 1000 non-null   object
#  34  CSL_Accidental               1000 non-null   object
#  35  policy_bind_day              1000 non-null   int64
#  36  policy_bind_month            1000 non-null   int64
#  37  policy_bind_year             1000 non-null   int64
#  38  incident_day                 1000 non-null   int64
#  39  incident_month               1000 non-null   int64
#  40  incident_year                1000 non-null   int64
# dtypes: float64(1), int64(21), object(19)
# memory usage: 320.4+ KB

# %%
df.nunique()
# Out:
# months_as_customer             391
# age                             46
# policy_state                     3
# policy_deductable                3
# policy_annual_premium          991
# umbrella_limit                  11
# insured_sex                      2
# insured_education_level          7
# insured_occupation              14
# insured_hobbies                 20
# insured_relationship             6
# capital-gains                  338
# capital-loss                   354
# incident_type                    4
# collision_type                   3
# incident_severity                4
# authorities_contacted            5
# incident_state                   7
# incident_city                    7
# incident_hour_of_the_day        24
# number_of_vehicles_involved      4
# property_damage                  2
# bodily_injuries                  3
# witnesses                        4
# police_report_available          2
# total_claim_amount             763
# injury_claim                   638
# property_claim                 626
# vehicle_claim                  726
# auto_make                       14
# auto_model                      39
# auto_year                       21
# fraud_reported                   2
# CSL_Personal                     3
# CSL_Accidental                   3
# policy_bind_day                 31
# policy_bind_month               12
# policy_bind_year                26
# incident_day                    22
# incident_month                  12
# incident_year                    1
# dtype: int64

# %% [markdown]
# - incident_year is having only one value of type which is 2015, lets drop feture incident_year

# %% [markdown]
# - It is read that, Auto year is the make of the year, this feature can be used to calculate the age of the vehicle, as we know, the dataset contain only incident_year as 2015, incident_year minus auto year will give us the age of the vehicle

# %%
# age of the vehicle calculation from auto_year by subtracting it from the year 2015
df['Automobile_Age']=2015 - df['auto_year']
# Droping auto year column
df.drop("auto_year",axis=1,inplace=True)

# %% [markdown]
# #### Splitting Neumerical and Categorical Feature

# %%
Category = ['policy_state',  'insured_sex', 'insured_education_level', 'insured_occupation', 
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted','incident_state', 'incident_city', 'property_damage','police_report_available',
            'auto_make','auto_model', 'fraud_reported']
    
Numerical = ['months_as_customer','CSL_Personal','CSL_Accidental', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss', 
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'Automobile_Age','policy_annual_premium']

# %% [markdown]
# #### Statistical View using Describe method

# %%
df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_61bcf_row0_col0, #T_61bcf_row0_col2, #T_61bcf_row1_col0, #T_61bcf_row1_col2, #T_61bcf_row2_col0, #T_61bcf_row2_col2, #T_61bcf_row3_col0, #T_61bcf_row3_col2, #T_61bcf_row4_col0, #T_61bcf_row5_col0, #T_61bcf_row6_col0, #T_61bcf_row6_col1, #T_61bcf_row6_col5, #T_61bcf_row7_col0, #T_61bcf_row7_col2, #T_61bcf_row8_col0, #T_61bcf_row8_col2, #T_61bcf_row9_col0, #T_61bcf_row9_col2, #T_61bcf_row10_col0, #T_61bcf_row10_col2, #T_61bcf_row11_col0, #T_61bcf_row12_col0, #T_61bcf_row12_col2, #T_61bcf_row13_col0, #T_61bcf_row13_col2, #T_61bcf_row14_col0, #T_61bcf_row15_col0, #T_61bcf_row15_col2, #T_61bcf_row16_col0, #T_61bcf_row16_col2, #T_61bcf_row17_col0, #T_61bcf_row17_col2, #T_61bcf_row18_col0, #T_61bcf_row18_col2, #T_61bcf_row19_col0, #T_61bcf_row19_col2, #T_61bcf_row20_col0, #T_61bcf_row20_col2, #T_61bcf_row21_col0, #T_61bcf_row21_col2 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_61bcf_row0_col1, #T_61bcf_row1_col1, #T_61bcf_row2_col1, #T_61bcf_row3_col1, #T_61bcf_row7_col1, #T_61bcf_row8_col1, #T_61bcf_row9_col1, #T_61bcf_row10_col1, #T_61bcf_row15_col1, #T_61bcf_row16_col1, #T_61bcf_row17_col1, #T_61bcf_row18_col1, #T_61bcf_row19_col1, #T_61bcf_row20_col1, #T_61bcf_row21_col1 {
#   background-color: #fff3ef;
#   color: #000000;
# }
# #T_61bcf_row0_col5, #T_61bcf_row1_col5, #T_61bcf_row4_col5, #T_61bcf_row5_col5, #T_61bcf_row7_col5, #T_61bcf_row8_col5, #T_61bcf_row9_col5, #T_61bcf_row10_col5, #T_61bcf_row15_col5, #T_61bcf_row16_col5, #T_61bcf_row18_col5, #T_61bcf_row19_col5, #T_61bcf_row21_col5 {
#   background-color: #fbbabd;
#   color: #000000;
# }
# #T_61bcf_row2_col5 {
#   background-color: #fbb6bc;
#   color: #000000;
# }
# #T_61bcf_row3_col5 {
#   background-color: #fbb5bb;
#   color: #000000;
# }
# #T_61bcf_row4_col1, #T_61bcf_row4_col2, #T_61bcf_row11_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_61bcf_row5_col1 {
#   background-color: #feefeb;
#   color: #000000;
# }
# #T_61bcf_row5_col2, #T_61bcf_row6_col2 {
#   background-color: #fff5f1;
#   color: #000000;
# }
# #T_61bcf_row11_col1 {
#   background-color: #feeae7;
#   color: #000000;
# }
# #T_61bcf_row11_col2, #T_61bcf_row14_col2 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_61bcf_row12_col1, #T_61bcf_row13_col1 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_61bcf_row12_col5, #T_61bcf_row13_col5 {
#   background-color: #faa1b6;
#   color: #000000;
# }
# #T_61bcf_row14_col1 {
#   background-color: #feede9;
#   color: #000000;
# }
# #T_61bcf_row14_col5 {
#   background-color: #98017b;
#   color: #f1f1f1;
# }
# #T_61bcf_row17_col5, #T_61bcf_row20_col5 {
#   background-color: #fbb3bb;
#   color: #000000;
# }
# </style>
# <table id="T_61bcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61bcf_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_61bcf_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_61bcf_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_61bcf_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_61bcf_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_61bcf_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_61bcf_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_61bcf_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61bcf_level0_row0" class="row_heading level0 row0" >months_as_customer</th>
#       <td id="T_61bcf_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_61bcf_row0_col1" class="data row0 col1" >203.954000</td>
#       <td id="T_61bcf_row0_col2" class="data row0 col2" >115.113174</td>
#       <td id="T_61bcf_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_61bcf_row0_col4" class="data row0 col4" >115.750000</td>
#       <td id="T_61bcf_row0_col5" class="data row0 col5" >199.500000</td>
#       <td id="T_61bcf_row0_col6" class="data row0 col6" >276.250000</td>
#       <td id="T_61bcf_row0_col7" class="data row0 col7" >479.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_61bcf_row1_col0" class="data row1 col0" >1000.000000</td>
#       <td id="T_61bcf_row1_col1" class="data row1 col1" >38.948000</td>
#       <td id="T_61bcf_row1_col2" class="data row1 col2" >9.140287</td>
#       <td id="T_61bcf_row1_col3" class="data row1 col3" >19.000000</td>
#       <td id="T_61bcf_row1_col4" class="data row1 col4" >32.000000</td>
#       <td id="T_61bcf_row1_col5" class="data row1 col5" >38.000000</td>
#       <td id="T_61bcf_row1_col6" class="data row1 col6" >44.000000</td>
#       <td id="T_61bcf_row1_col7" class="data row1 col7" >64.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row2" class="row_heading level0 row2" >policy_deductable</th>
#       <td id="T_61bcf_row2_col0" class="data row2 col0" >1000.000000</td>
#       <td id="T_61bcf_row2_col1" class="data row2 col1" >1136.000000</td>
#       <td id="T_61bcf_row2_col2" class="data row2 col2" >611.864673</td>
#       <td id="T_61bcf_row2_col3" class="data row2 col3" >500.000000</td>
#       <td id="T_61bcf_row2_col4" class="data row2 col4" >500.000000</td>
#       <td id="T_61bcf_row2_col5" class="data row2 col5" >1000.000000</td>
#       <td id="T_61bcf_row2_col6" class="data row2 col6" >2000.000000</td>
#       <td id="T_61bcf_row2_col7" class="data row2 col7" >2000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row3" class="row_heading level0 row3" >policy_annual_premium</th>
#       <td id="T_61bcf_row3_col0" class="data row3 col0" >1000.000000</td>
#       <td id="T_61bcf_row3_col1" class="data row3 col1" >1256.406150</td>
#       <td id="T_61bcf_row3_col2" class="data row3 col2" >244.167395</td>
#       <td id="T_61bcf_row3_col3" class="data row3 col3" >433.330000</td>
#       <td id="T_61bcf_row3_col4" class="data row3 col4" >1089.607500</td>
#       <td id="T_61bcf_row3_col5" class="data row3 col5" >1257.200000</td>
#       <td id="T_61bcf_row3_col6" class="data row3 col6" >1415.695000</td>
#       <td id="T_61bcf_row3_col7" class="data row3 col7" >2047.590000</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row4" class="row_heading level0 row4" >umbrella_limit</th>
#       <td id="T_61bcf_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_61bcf_row4_col1" class="data row4 col1" >1101000.000000</td>
#       <td id="T_61bcf_row4_col2" class="data row4 col2" >2297406.598118</td>
#       <td id="T_61bcf_row4_col3" class="data row4 col3" >-1000000.000000</td>
#       <td id="T_61bcf_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_61bcf_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_61bcf_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_61bcf_row4_col7" class="data row4 col7" >10000000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row5" class="row_heading level0 row5" >capital-gains</th>
#       <td id="T_61bcf_row5_col0" class="data row5 col0" >1000.000000</td>
#       <td id="T_61bcf_row5_col1" class="data row5 col1" >25126.100000</td>
#       <td id="T_61bcf_row5_col2" class="data row5 col2" >27872.187708</td>
#       <td id="T_61bcf_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_61bcf_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_61bcf_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_61bcf_row5_col6" class="data row5 col6" >51025.000000</td>
#       <td id="T_61bcf_row5_col7" class="data row5 col7" >100500.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61bcf_level0_row6" class="row_heading level0 row6" >capital-loss</th>
#       <td id="T_61bcf_row6_col0" class="data row6 col0" >1000.000000</td>
#       <td id="T_61bcf_row6_col1" class="data row6 col1" >-26793.700000</td>
#       <td id="T_61bcf_row6_col2" class="data row6 col2" >28104.096686</td>
#       <td id="T_61bcf_row6_col3" class="data row6 col3" >-111100.000000</td>
#       <td id="T_61bcf_row6_col4" class="data row6 col4" >-51500.000000</td>
#       <td id="T_61bcf_row6_col5" c

# %%
df[Category].describe().T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5d7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5d7d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_c5d7d_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_c5d7d_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_c5d7d_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5d7d_level0_row0" class="row_heading level0 row0" >policy_state</th>
#       <td id="T_c5d7d_row0_col0" class="data row0 col0" >1000</td>
#       <td id="T_c5d7d_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_c5d7d_row0_col2" class="data row0 col2" >OH</td>
#       <td id="T_c5d7d_row0_col3" class="data row0 col3" >352</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row1" class="row_heading level0 row1" >insured_sex</th>
#       <td id="T_c5d7d_row1_col0" class="data row1 col0" >1000</td>
#       <td id="T_c5d7d_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_c5d7d_row1_col2" class="data row1 col2" >FEMALE</td>
#       <td id="T_c5d7d_row1_col3" class="data row1 col3" >537</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row2" class="row_heading level0 row2" >insured_education_level</th>
#       <td id="T_c5d7d_row2_col0" class="data row2 col0" >1000</td>
#       <td id="T_c5d7d_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_c5d7d_row2_col2" class="data row2 col2" >JD</td>
#       <td id="T_c5d7d_row2_col3" class="data row2 col3" >161</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row3" class="row_heading level0 row3" >insured_occupation</th>
#       <td id="T_c5d7d_row3_col0" class="data row3 col0" >1000</td>
#       <td id="T_c5d7d_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_c5d7d_row3_col2" class="data row3 col2" >machine-op-inspct</td>
#       <td id="T_c5d7d_row3_col3" class="data row3 col3" >93</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row4" class="row_heading level0 row4" >insured_hobbies</th>
#       <td id="T_c5d7d_row4_col0" class="data row4 col0" >1000</td>
#       <td id="T_c5d7d_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_c5d7d_row4_col2" class="data row4 col2" >reading</td>
#       <td id="T_c5d7d_row4_col3" class="data row4 col3" >64</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row5" class="row_heading level0 row5" >insured_relationship</th>
#       <td id="T_c5d7d_row5_col0" class="data row5 col0" >1000</td>
#       <td id="T_c5d7d_row5_col1" class="data row5 col1" >6</td>
#       <td id="T_c5d7d_row5_col2" class="data row5 col2" >own-child</td>
#       <td id="T_c5d7d_row5_col3" class="data row5 col3" >183</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row6" class="row_heading level0 row6" >incident_type</th>
#       <td id="T_c5d7d_row6_col0" class="data row6 col0" >1000</td>
#       <td id="T_c5d7d_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_c5d7d_row6_col2" class="data row6 col2" >Multi-vehicle Collision</td>
#       <td id="T_c5d7d_row6_col3" class="data row6 col3" >419</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row7" class="row_heading level0 row7" >collision_type</th>
#       <td id="T_c5d7d_row7_col0" class="data row7 col0" >1000</td>
#       <td id="T_c5d7d_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_c5d7d_row7_col2" class="data row7 col2" >Rear Collision</td>
#       <td id="T_c5d7d_row7_col3" class="data row7 col3" >470</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row8" class="row_heading level0 row8" >incident_severity</th>
#       <td id="T_c5d7d_row8_col0" class="data row8 col0" >1000</td>
#       <td id="T_c5d7d_row8_col1" class="data row8 col1" >4</td>
#       <td id="T_c5d7d_row8_col2" class="data row8 col2" >Minor Damage</td>
#       <td id="T_c5d7d_row8_col3" class="data row8 col3" >354</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row9" class="row_heading level0 row9" >authorities_contacted</th>
#       <td id="T_c5d7d_row9_col0" class="data row9 col0" >1000</td>
#       <td id="T_c5d7d_row9_col1" class="data row9 col1" >5</td>
#       <td id="T_c5d7d_row9_col2" class="data row9 col2" >Police</td>
#       <td id="T_c5d7d_row9_col3" class="data row9 col3" >292</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row10" class="row_heading level0 row10" >incident_state</th>
#       <td id="T_c5d7d_row10_col0" class="data row10 col0" >1000</td>
#       <td id="T_c5d7d_row10_col1" class="data row10 col1" >7</td>
#       <td id="T_c5d7d_row10_col2" class="data row10 col2" >NY</td>
#       <td id="T_c5d7d_row10_col3" class="data row10 col3" >262</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row11" class="row_heading level0 row11" >incident_city</th>
#       <td id="T_c5d7d_row11_col0" class="data row11 col0" >1000</td>
#       <td id="T_c5d7d_row11_col1" class="data row11 col1" >7</td>
#       <td id="T_c5d7d_row11_col2" class="data row11 col2" >Springfield</td>
#       <td id="T_c5d7d_row11_col3" class="data row11 col3" >157</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row12" class="row_heading level0 row12" >property_damage</th>
#       <td id="T_c5d7d_row12_col0" class="data row12 col0" >1000</td>
#       <td id="T_c5d7d_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_c5d7d_row12_col2" class="data row12 col2" >NO</td>
#       <td id="T_c5d7d_row12_col3" class="data row12 col3" >698</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row13" class="row_heading level0 row13" >police_report_available</th>
#       <td id="T_c5d7d_row13_col0" class="data row13 col0" >1000</td>
#       <td id="T_c5d7d_row13_col1" class="data row13 col1" >2</td>
#       <td id="T_c5d7d_row13_col2" class="data row13 col2" >NO</td>
#       <td id="T_c5d7d_row13_col3" class="data row13 col3" >686</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row14" class="row_heading level0 row14" >auto_make</th>
#       <td id="T_c5d7d_row14_col0" class="data row14 col0" >1000</td>
#       <td id="T_c5d7d_row14_col1" class="data row14 col1" >14</td>
#       <td id="T_c5d7d_row14_col2" class="data row14 col2" >Saab</td>
#       <td id="T_c5d7d_row14_col3" class="data row14 col3" >80</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row15" class="row_heading level0 row15" >auto_model</th>
#       <td id="T_c5d7d_row15_col0" class="data row15 col0" >1000</td>
#       <td id="T_c5d7d_row15_col1" class="data row15 col1" >39</td>
#       <td id="T_c5d7d_row15_col2" class="data row15 col2" >RAM</td>
#       <td id="T_c5d7d_row15_col3" class="data row15 col3" >43</td>
#     </tr>
#     <tr>
#       <th id="T_c5d7d_level0_row16" class="row_heading level0 row16" >fraud_reported</th>
#       <td id="T_c5d7d_row16_col0" class="data row16 col0" >1000</td>
#       <td id="T_c5d7d_row16_col1" class="data row16 col1" >2</td>
#       <td id="T_c5d7d_row16_col2" class="data row16 col2" >N</td>
#       <td id="T_c5d7d_row16_col3" class="data row16 col3" >753</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Categorical features Further analysis - unique value counts/values

# %%
for i in Category:
    print(i)
    print(df[i].value_counts())
    print("-"*100)
# Out:
# policy_state
# OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# ----------------------------------------------------------------------------------------------------
# insured_sex
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64
# ----------------------------------------------------------------------------------------------------
# insured_education_level
# JD             161
# High School    160
# Associate      145
# MD             144
# Masters        143
# PhD            125
# College        122
# Name: insured_education_level, dtype: int64
# ----------------------------------------------------------------------------------------------------
# insured_occupation
# machine-op-inspct    93
# prof-specialty       85
# tech-support         78
# sales                76
# exec-managerial      76
# craft-repair         74
# transport-moving     72
# other-service        71
# priv-house-serv      71
# armed-forces         69
# adm-clerical         65
# protective-serv      63
# handlers-cleaners    54
# farming-fishing      53
# Name: insured_occupation, dtype: int64
# ----------------------------------------------------------------------------------------------------
# insured_hobbies
# reading           64
# exercise          57
# paintball         57
# bungie-jumping    56
# movies            55
# golf              55
# camping           55
# kayaking          54
# yachting          53
# hiking            52
# video-games       50
# skydiving         49
# base-jumping      49
# board-games       48
# polo              47
# chess             46
# dancing           43
# sleeping          41
# cross-fit         35
# basketball        34
# Name: insured_hobbies, dtype: int64
# ----------------------------------------------------------------------------------------------------
# insured_relationship
# own-child         183
# other-relative    177
# not-in-family     174
# husband           170
# wife              155
# unmarried         141
# Name: insured_relationship, dtype: int64
# ----------------------------------------------------------------------------------------------------
# incident_type
# Multi-vehicle Collision     419
# Single Vehicle Collision    403
# Vehicle Theft                94
# Parked Car                   84
# Name: incident_type, dtype: int64
# ----------------------------------------------------------------------------------------------------
# collision_type
# Rear Collision     470
# Side Collision     276
# Front Collision    254
# Name: collision_type, dtype: int64
# ----------------------------------------------------------------------------------------------------
# incident_severity
# Minor Damage      354
# Total Loss        280
# Major Damage      276
# Trivial Damage     90
# Name: incident_severity, dtype: int64
# ----------------------------------------------------------------------------------------------------
# authorities_contacted
# Police       292
# Fire         223
# Other        198
# Ambulance    196
# None          91
# Name: authorities_contacted, dtype: int64
# ----------------------------------------------------------------------------------------------------
# incident_state
# NY    262
# SC    248
# WV    217
# VA    110
# NC    110
# PA     30
# OH     23
# Name: incident_state, dtype: int64
# ----------------------------------------------------------------------------------------------------
# incident_city
# Springfield    157
# Arlington      152
# Columbus       149
# Northbend      145
# Hillsdale      141
# Riverwood      134
# Northbrook     122
# Name: incident_city, dtype: int64
# ----------------------------------------------------------------------------------------------------
# property_damage
# NO     698
# YES    302
# Name: property_damage, dtype: int64
# ----------------------------------------------------------------------------------------------------
# police_report_available
# NO     686
# YES    314
# Name: police_report_available, dtype: int64
# ----------------------------------------------------------------------------------------------------
# auto_make
# Saab          80
# Dodge         80
# Suburu        80
# Nissan        78
# Chevrolet     76
# Ford          72
# BMW           72
# Toyota        70
# Audi          69
# Accura        68
# Volkswagen    68
# Jeep          67
# Mercedes      65
# Honda         55
# Name: auto_make, dtype: int64
# ----------------------------------------------------------------------------------------------------
# auto_model
# RAM               43
# Wrangler          42
# A3                37
# Neon              37
# MDX               36
# Jetta             35
# Passat            33
# A5                32
# Legacy            32
# Pathfinder        31
# Malibu            30
# 92x               28
# Camry             28
# Forrestor         28
# F150              27
# 95                27
# E400              27
# 93                25
# Grand Cherokee    25
# Escape            24
# Tahoe             24
# Maxima            24
# Ultima            23
# X5                23
# Highlander        22
# Civic             22
# Silverado         22
# Fusion            21
# ML350             20
# Impreza           20
# Corolla           20
# TL                20
# CRV               20
# C300              18
# 3 Series          18
# X6                16
# M5                15
# Accord            13
# RSX               12
# Name: auto_model, dtype: int64
# ----------------------------------------------------------------------------------------------------
# fraud_reported
# N    753
# Y    247
# Name: fraud_reported, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Target Variable Analysis

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(12,7))
df['fraud_reported'].value_counts().plot.pie(explode=[0,0.1],autopct='%3.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':10}, ax=ax[0],shadow=True)
ax[0].set_title('Fraud Case ditrbn', fontsize=12,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('fraud_reported',data=df,ax=ax[1])
ax[1].set_title('Fraud Cases Count',fontsize=12,fontweight ='bold')
ax[1].set_xlabel("Fraud Cases",fontsize=10,fontweight ='bold')
plt.xticks(fontsize=10,fontweight ='bold')
plt.show()

# %% [markdown]
# - From the count plot, its seen that the Target variable dataset is imbalanced in nature.
# - Only 24.7 cases are Fraud on each 100 cases

# %% [markdown]
# - Lets check How each individual feature are contributing to Target Varaible

# %% [markdown]
# #### Age v/s Fraud cases Behaviour

# %%
# taking the Age Classes for plotting in graph
print('Minimum Age :',df.age.min(),'Years')
print('Maximum Age :',df.age.max(),'Years')
print('Average Age :',df.age.mean(),'Years')
# Out:
# Minimum Age : 19 Years
# Maximum Age : 64 Years
# Average Age : 38.948 Years

# %%
plt.figure(figsize=(7,6))
sns.histplot(df.age, kde=True, color='b')
plt.xlabel('Age',fontsize=16)
plt.title('Age Distribution', fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# - For Better Clarity lets devide Age into more classes

# %%
# Spliting age in different age range
df['age_bins'] = pd.cut(df.age, bins = [0, 10, 20, 30, 40, 50, 60, 70], 
                          include_lowest = True, labels = ['0-10','11-20','21-30','31-40', '41-50', '51-60', '61-70'])

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df.age_bins, hue=df.fraud_reported)
plt.xlabel('Age',fontsize=18,fontweight ='bold')
plt.title('Age Disbn Vs Fraud Cases', fontsize=20,fontweight ='bold')
plt.show()

# %% [markdown]
# - Fraud Tendency is more in thr age group 31-40 and then 41-50 and then in 21-30 very lerast in 61-70(less population)

# %% [markdown]
# #### policy_States V/s Fraud Cases

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['policy_state'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder State Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['policy_state'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Statewise Proportion of Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" State ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Almost same in each states,
# - Max Fraud  case in the State OH

# %% [markdown]
# #### Insured Gender v/s Fraud cases

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['insured_sex'].value_counts().plot.pie(explode=[0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Gender Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['insured_sex'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Genderwise Proportion of Fraud cases',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Gender ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Fraud rate same for Male and Female

# %% [markdown]
# #### education_level v/s Fraud cases

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['insured_education_level'].value_counts().plot.pie(explode=[0.03,0.03,0.03,0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Policy-holder Education_level Distribution', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['insured_education_level'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases vs Policy-holder Education_level ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel(" Education_level ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Almost all Education Level people are having involments in Fraud activities, so Education is not at all a matter, Frauds are Frauds in every Education Level

# %% [markdown]
# #### Occupation and Hobbies of Insured Customers - jsut study

# %%
# let's check the insured occupation
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11, 8)
sns.countplot(df['insured_occupation'], palette = 'gist_earth')
plt.title('Different Types of Occupation of Insured Customers' ,fontsize=20,fontweight ='bold')
plt.xticks(rotation = 90)
plt.show()

# %%
# let's check the insured customers hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15, 8)
sns.countplot(df['insured_hobbies'], palette = 'cool')
plt.title('Different Types of Hobbies of Insured Customers',fontsize=20,fontweight ='bold')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# #### Diff Types of Incidents Vs Fraud cases

# %%
# let's check the incident types
plt.rcParams['figure.figsize'] = (10,5)
sns.countplot(df['incident_type'], palette = 'Dark2')
plt.title('Different Types of Incidents',fontsize=20,fontweight ='bold')
plt.xlabel('Different Types of Incidents', fontsize=18,fontweight='bold')
plt.ylabel('Population', fontsize=18,fontweight='bold')
plt.xticks(fontweight ='bold')
plt.show()

# %% [markdown]
# - Single and Multi Vehicle collission are major type of incidents

# %% [markdown]
# #### Fraud Cases v/s Insurance Type

# %%
# let's check the insured hobbies
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,7)
table = pd.crosstab(df['incident_type'], df['fraud_reported'])
table.plot(kind = 'bar')
plt.title('Fraud cases As per Incident Type',fontsize=20,fontweight ='bold')
plt.xlabel('Different Incidents', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %% [markdown]
# - Fraud Cases are more in Collissions weather it is Multi-vehicle Collission or Single Vehicle Collission

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['collision_type'].value_counts().plot.pie(explode=[0.03,0.03,0.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['collision_type'], df['fraud_reported'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Fraud cases in different Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# - More Fraud cases in Rear Collission

# %%
# let's check the incident type v/s  collission type
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (10,6)
sns.set_palette('coolwarm')
table = pd.crosstab(df['incident_type'], df['collision_type'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar',stacked=True)
plt.title(' Incident Type VS Collision Type',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=12,fontweight='bold')
plt.xticks(fontsize=13,rotation=0,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Collision v/s Incident Severity

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set2_r')
fig,ax=plt.subplots(1,2,figsize=(16,7))
df['incident_severity'].value_counts().plot.pie(explode=[0.03,0.03,0.03,.03],autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('Severity of Collision Pie Chart', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')

table = pd.crosstab(df['incident_severity'], df['collision_type'])
table.plot(kind = 'bar', ax=ax[1])
ax[1].set_title('Incident Severity vs Collision Type ',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("Collision Type ",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=14,fontweight ='bold',rotation=0)
plt.tight_layout()
plt.show()

# %%
pd.crosstab(df['incident_type'], df['incident_severity']).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_ebc64_row0_col0, #T_ebc64_row0_col2, #T_ebc64_row2_col1, #T_ebc64_row3_col3 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_ebc64_row0_col1 {
#   background-color: #108866;
#   color: #f1f1f1;
# }
# #T_ebc64_row0_col3, #T_ebc64_row1_col0, #T_ebc64_row1_col1, #T_ebc64_row1_col2, #T_ebc64_row2_col3, #T_ebc64_row3_col0, #T_ebc64_row3_col2 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_ebc64_row1_col3 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_ebc64_row2_col0 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_ebc64_row2_col2 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_ebc64_row3_col1 {
#   background-color: #f5fa66;
#   color: #000000;
# }
# </style>
# <table id="T_ebc64">
#   <thead>
#     <tr>
#       <th class="index_name level0" >incident_severity</th>
#       <th id="T_ebc64_level0_col0" class="col_heading level0 col0" >Major Damage</th>
#       <th id="T_ebc64_level0_col1" class="col_heading level0 col1" >Minor Damage</th>
#       <th id="T_ebc64_level0_col2" class="col_heading level0 col2" >Total Loss</th>
#       <th id="T_ebc64_level0_col3" class="col_heading level0 col3" >Trivial Damage</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >incident_type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebc64_level0_row0" class="row_heading level0 row0" >Multi-vehicle Collision</th>
#       <td id="T_ebc64_row0_col0" class="data row0 col0" >144</td>
#       <td id="T_ebc64_row0_col1" class="data row0 col1" >130</td>
#       <td id="T_ebc64_row0_col2" class="data row0 col2" >145</td>
#       <td id="T_ebc64_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ebc64_level0_row1" class="row_heading level0 row1" >Parked Car</th>
#       <td id="T_ebc64_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_ebc64_row1_col1" class="data row1 col1" >42</td>
#       <td id="T_ebc64_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_ebc64_row1_col3" class="data row1 col3" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ebc64_level0_row2" class="row_heading level0 row2" >Single Vehicle Collision</th>
#       <td id="T_ebc64_row2_col0" class="data row2 col0" >132</td>
#       <td id="T_ebc64_row2_col1" class="data row2 col1" >136</td>
#       <td id="T_ebc64_row2_col2" class="data row2 col2" >135</td>
#       <td id="T_ebc64_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ebc64_level0_row3" class="row_heading level0 row3" >Vehicle Theft</th>
#       <td id="T_ebc64_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_ebc64_row3_col1" class="data row3 col1" >46</td>
#       <td id="T_ebc64_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_ebc64_row3_col3" class="data row3 col3" >48</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Incident Type v/s Incident_severity
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.set_palette('summer_r')
table = pd.crosstab(df['incident_type'], df['incident_severity'])
(table.div(table.sum(axis=1),axis=0)*100).plot(kind='bar')
plt.title(' Incident Type v/s incident_severity',fontsize=20,fontweight ='bold')
plt.xlabel('Collision', fontsize=16,fontweight='bold')
plt.xticks(fontsize=14,rotation=0,fontweight ='bold')
plt.show()

# %% [markdown]
# - Incident_type seems to be an important variable, lets explore more with this feature and its relationship with other neumerical and categoricals

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (13,7)
sns.boxenplot(df['incident_type'], df['vehicle_claim'], palette = 'magma')
plt.title('Incident Type vs Vehicle Claim',fontsize=20,fontweight ='bold')
plt.xlabel('Incident Type', fontsize=16,fontweight='bold')
plt.ylabel('Vehicle Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11,7)
sns.stripplot(df['property_damage'], df['property_claim'], palette = 'bone')
plt.title('Incident Type vs Vehicle Claim',fontsize=20,fontweight ='bold')
plt.xlabel('Property Damage', fontsize=16,fontweight='bold')
plt.ylabel('Property claim', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (11,7)
sns.swarmplot(df['policy_state'], df['total_claim_amount'], palette = 'copper')
plt.title('Total Claim Amount in Differnt State',fontsize=20,fontweight ='bold')
plt.xlabel('State', fontsize=16,fontweight='bold')
plt.ylabel('Total claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,9)
sns.boxplot(df['auto_make'], df['vehicle_claim'], palette = 'summer_r')
plt.title('Vehicle Claim Amount for different Automobile Makers',fontsize=20,fontweight ='bold')
plt.xlabel('Automobile Makers', fontsize=16,fontweight='bold')
plt.ylabel('Vehicle Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,9)
sns.scatterplot(df['policy_annual_premium'], df['total_claim_amount'], hue=df.fraud_reported, palette = 'Set1')
plt.title('Total Claim Amount VS Annual Premium',fontsize=20,fontweight ='bold')
plt.xlabel('Policy Annual Premium', fontsize=16,fontweight='bold')
plt.ylabel('Total Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
# swarm plot
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (12,8)
sns.violinplot(df['incident_severity'], df['total_claim_amount'], hue=df.fraud_reported, palette = 'Set1')
plt.title('Incident Severity VS Total Claim Amount',fontsize=20,fontweight ='bold')
plt.xlabel('Incident Severity', fontsize=16,fontweight='bold')
plt.ylabel('Total Claim Amount', fontsize=16,fontweight='bold')
plt.show()

# %%
pd.set_option('display.max_columns', None) # This will enable us to see truncated columns
df.head()
# Out:
#    months_as_customer  age policy_state  policy_deductable  \
# 0                 328   48           OH               1000
# 1                 228   42           IN               2000
# 2                 134   29           OH               2000
# 3                 256   41           IL               2000
# 4                 228   44           IL               1000
#
#    policy_annual_premium  umbrella_limit insured_sex insured_education_level  \
# 0                1406.91               0        MALE                      MD
# 1                1197.22         5000000        MALE                      MD
# 2                1413.14         5000000      FEMALE                     PhD
# 3                1415.74         6000000      FEMALE                     PhD
# 4                1583.91         6000000        MALE               Associate
#
#   insured_occupation insured_hobbies insured_relationship  capital-gains  \
# 0       craft-repair        sleeping              husband          53300
# 1  machine-op-inspct         reading       other-relative              0
# 2              sales     board-games            own-child          35100
# 3       armed-forces     board-games            unmarried          48900
# 4              sales     board-games            unmarried          66000
#
#    capital-loss             incident_type   collision_type incident_severity  \
# 0             0  Single Vehicle Collision   Side Collision      Major Damage
# 1             0             Vehicle Theft                ?      Minor Damage
# 2             0   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3        -62400  Single Vehicle Collision  Front Collision      Major Damage
# 4        -46000             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  \
# 0                Police             SC      Columbus
# 1                Police             VA     Riverwood
# 2                Police             NY      Columbus
# 3                Police             OH     Arlington
# 4                  None             NY     Arlington
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#   fraud_reported CSL_Personal CSL_Accidental  policy_bind_day  \
# 0              Y          250            500               17
# 1              Y          250            500               27
# 2              N          100            300                9
# 3              Y          250            500               25
# 4              N          500           1000                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    incident_year  Automobile_Age
# 0           2015              11
# 1           2015               8
# 2           2015               8
# 3           2015               1
# 4           2015               6

# %% [markdown]
# #### Encoding Categorical Data

# %%
Category = ['policy_state', 'insured_sex', 'insured_education_level', 'insured_occupation',
            'insured_hobbies', 'insured_relationship', 'incident_type', 'collision_type', 'incident_severity',
            'authorities_contacted', 'incident_state', 'incident_city', 'property_damage', 'police_report_available', 
            'auto_make', 'auto_model', 'fraud_reported', 'CSL_Personal', 'CSL_Accidental']

# %%
# Encoding Using Label Encoder- categorical features
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Category:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               3                  0                      4               4
# 1               0                  1                      4               5
# 2               2                  1                      4               1
# 3               1                  0                      4               2
# 4               0                  1                      2               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                2                1          2                        2
# 1                0                0          0                        0
# 2                1                2          3                        1
# 3                0                1          2                        1
# 4                1                0          1                        1
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                9
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    incident_year  Automobile_Age
# 0           2015              11
# 1           2015               8
# 2           2015               8
# 3           2015               1
# 4           2015               6

# %% [markdown]
# #### Feature Selection and Engng

# %% [markdown]
# <b>Outliers Detection and Removal<b>

# %%
Numerical = ['months_as_customer', 'age', 'policy_deductable', 'umbrella_limit', 'capital-gains', 'capital-loss',
             'incident_hour_of_the_day', 'number_of_vehicles_involved', 'bodily_injuries', 'witnesses', 
             'total_claim_amount','injury_claim', 'property_claim', 'vehicle_claim', 'policy_bind_day', 
             'policy_bind_month', 'policy_bind_year', 'incident_day', 'incident_month', 'Automobile_Age','policy_annual_premium']

# %%
# Outliers using Box plot

plt.figure(figsize=(20,30),facecolor='white')
plotnumber=1

for column in Numerical:
    if plotnumber<=21:
        ax=plt.subplot(7,3,plotnumber)
        sns.boxplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# - Outliers Exists in the Data

# %% [markdown]
# <b>Outliers removal using Zscore<b>

# %%
df.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               3                  0                      4               4
# 1               0                  1                      4               5
# 2               2                  1                      4               1
# 3               1                  0                      4               2
# 4               0                  1                      2               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                2                1          2                        2
# 1                0                0          0                        0
# 2                1                2          3                        1
# 3                0                1          2                        1
# 4                1                0          1                        1
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                9
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    incident_year  Automobile_Age
# 0           2015              11
# 1           2015               8
# 2           2015               8
# 3           2015               1
# 4           2015               6

# %%
df2= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/Automobile_insurance_fraud.csv')

# %%
df2.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       17-10-2014           OH
# 1                 228   42         342868       27-06-2006           IN
# 2                 134   29         687698       06-09-2000           OH
# 3                 256   41         227811       25-05-1990           IL
# 4                 228   44         367455       06-06-2014           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip insured_sex insured_education_level insured_occupation  \
# 0       466132        MALE                      MD       craft-repair
# 1       468176        MALE                      MD  machine-op-inspct
# 2       430632      FEMALE                     PhD              sales
# 3       608117      FEMALE                     PhD       armed-forces
# 4       610706        MALE               Associate              sales
#
#   insured_hobbies insured_relationship  capital-gains  capital-loss  \
# 0        sleeping              husband          53300             0
# 1         reading       other-relative              0             0
# 2     board-games            own-child          35100             0
# 3     board-games            unmarried          48900        -62400
# 4     board-games            unmarried          66000        -46000
#
#   incident_date             incident_type   collision_type incident_severity  \
# 0    25-01-2015  Single Vehicle Collision   Side Collision      Major Damage
# 1    21-01-2015             Vehicle Theft                ?      Minor Damage
# 2    22-02-2015   Multi-vehicle Collision   Rear Collision      Minor Damage
# 3    10-01-2015  Single Vehicle Collision  Front Collision      Major Damage
# 4    17-02-2015             Vehicle Theft                ?      Minor Damage
#
#   authorities_contacted incident_state incident_city  incident_location  \
# 0                Police             SC      Columbus     9935 4th Drive
# 1                Police             VA     Riverwood       6608 MLK Hwy
# 2                Police             NY      Columbus  7121 Francis Lane
# 3                Police             OH     Arlington   6956 Maple Drive
# 4                  None             NY     Arlington       3041 3rd Ave
#
#    incident_hour_of_the_day  number_of_vehicles_involved property_damage  \
# 0                         5                            1             YES
# 1                         8                            1               ?
# 2                         7                            3              NO
# 3                         5                            1               ?
# 4                        20                            1              NO
#
#    bodily_injuries  witnesses police_report_available  total_claim_amount  \
# 0                1          2                     YES               71610
# 1                0          0                       ?                5070
# 2                2          3                      NO               34650
# 3                1          2                      NO               63400
# 4                0          1                      NO                6500
#
#    injury_claim  property_claim  vehicle_claim  auto_make auto_model  \
# 0          6510           13020          52080       Saab        92x
# 1           780             780           3510   Mercedes       E400
# 2          7700            3850          23100      Dodge        RAM
# 3          6340            6340          50720  Chevrolet      Tahoe
# 4          1300             650           4550     Accura        RSX
#
#    auto_year fraud_reported  _c39
# 0       2004              Y   NaN
# 1       2007              Y   NaN
# 2       2007              N   NaN
# 3       2014              Y   NaN
# 4       2009              N   NaN

# %%
df.dtypes
# Out:
# months_as_customer                int64
# age                               int64
# policy_state                      int32
# policy_deductable                 int64
# policy_annual_premium           float64
# umbrella_limit                    int64
# insured_sex                       int32
# insured_education_level           int32
# insured_occupation                int32
# insured_hobbies                   int32
# insured_relationship              int32
# capital-gains                     int64
# capital-loss                      int64
# incident_type                     int32
# collision_type                    int32
# incident_severity                 int32
# authorities_contacted             int32
# incident_state                    int32
# incident_city                     int32
# incident_hour_of_the_day          int64
# number_of_vehicles_involved       int64
# property_damage                   int32
# bodily_injuries                   int64
# witnesses                         int64
# police_report_available           int32
# total_claim_amount                int64
# injury_claim                      int64
# property_claim                    int64
# vehicle_claim                     int64
# auto_make                         int32
# auto_model                        int32
# fraud_reported                    int32
# CSL_Personal                      int32
# CSL_Accidental                    int32
# policy_bind_day                   int64
# policy_bind_month                 int64
# policy_bind_year                  int64
# incident_day                      int64
# incident_month                    int64
# incident_year                     int64
# Automobile_Age                    int64
# age_bins                       category
# dtype: object

# %%
# We missed to delete Incident year as it has only one value, 2015, we made coputation for Age of the vehicle also

df.drop('incident_year',axis=1, inplace=True)
df.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               3                  0                      4               4
# 1               0                  1                      4               5
# 2               2                  1                      4               1
# 3               1                  0                      4               2
# 4               0                  1                      2               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                2                1          2                        2
# 1                0                0          0                        0
# 2                1                2          3                        1
# 3                0                1          2                        1
# 4                1                0          1                        1
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                9
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    Automobile_Age
# 0              11
# 1               8
# 2               8
# 3               1
# 4               6

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]
#z
print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)

#df=df1.copy()
# Out:
# Shape of the dataframe before removing outliers:  (1000, 40)
# Shape of the dataframe after removing outliers:  (980, 40)
# Percentage of data loss post outlier removal:  2.0

# %%
df1.head()
# Out:
#    months_as_customer  age  policy_state  policy_deductable  \
# 0                 328   48             2               1000
# 1                 228   42             1               2000
# 2                 134   29             2               2000
# 3                 256   41             0               2000
# 4                 228   44             0               1000
#
#    policy_annual_premium  umbrella_limit  insured_sex  \
# 0                1406.91               0            1
# 1                1197.22         5000000            1
# 2                1413.14         5000000            0
# 3                1415.74         6000000            0
# 4                1583.91         6000000            1
#
#    insured_education_level  insured_occupation  insured_hobbies  \
# 0                        4                   2               17
# 1                        4                   6               15
# 2                        6                  11                2
# 3                        6                   1                2
# 4                        0                  11                2
#
#    insured_relationship  capital-gains  capital-loss  incident_type  \
# 0                     0          53300             0              2
# 1                     2              0             0              3
# 2                     3          35100             0              0
# 3                     4          48900        -62400              2
# 4                     4          66000        -46000              3
#
#    collision_type  incident_severity  authorities_contacted  incident_state  \
# 0               3                  0                      4               4
# 1               0                  1                      4               5
# 2               2                  1                      4               1
# 3               1                  0                      4               2
# 4               0                  1                      2               1
#
#    incident_city  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0              1                         5                            1
# 1              5                         8                            1
# 2              1                         7                            3
# 3              0                         5                            1
# 4              0                        20                            1
#
#    property_damage  bodily_injuries  witnesses  police_report_available  \
# 0                2                1          2                        2
# 1                0                0          0                        0
# 2                1                2          3                        1
# 3                0                1          2                        1
# 4                1                0          1                        1
#
#    total_claim_amount  injury_claim  property_claim  vehicle_claim  auto_make  \
# 0               71610          6510           13020          52080         10
# 1                5070           780             780           3510          8
# 2               34650          7700            3850          23100          4
# 3               63400          6340            6340          50720          3
# 4                6500          1300             650           4550          0
#
#    auto_model  fraud_reported  CSL_Personal  CSL_Accidental  policy_bind_day  \
# 0           1               1             1               2               17
# 1          12               1             1               2               27
# 2          30               0             0               1                9
# 3          34               1             1               2               25
# 4          31               0             2               0                6
#
#    policy_bind_month  policy_bind_year  incident_day  incident_month  \
# 0                 10              2014            25               1
# 1                  6              2006            21               1
# 2                  6              2000            22               2
# 3                  5              1990             1              10
# 4                  6              2014            17               2
#
#    Automobile_Age
# 0              11
# 1               8
# 2               8
# 3               1
# 4               6

# %%
## Copying the Df1 to Df

df=df1.copy()

# %% [markdown]
# - Outliers are negligibly small- 2% and can be removed

# %% [markdown]
# <b>Skewness Of the Features<b>

# %%
# Using Dist Plot
plt.figure(figsize=(20,30),facecolor='white')
sns.set_palette('plasma')
plotnum=1
for col in Numerical:
    if plotnum<=21:
        plt.subplot(7,3,plotnum)
        sns.distplot(df[col])
        plt.xlabel(col,fontsize=20)
    plotnum+=1
plt.show()

# %% [markdown]
# - Taking into consideration only for the skewness in Continous Data and not consoidersing skewnwss in Target data and descrete data features

# %%
# Skewness Check using .skew() method
df[Numerical].skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_deductable              0.476090
# umbrella_limit                 1.801424
# capital-gains                  0.466619
# capital-loss                  -0.376884
# incident_hour_of_the_day      -0.039280
# number_of_vehicles_involved    0.509725
# bodily_injuries                0.003757
# witnesses                      0.026211
# total_claim_amount            -0.593593
# injury_claim                   0.271759
# property_claim                 0.361356
# vehicle_claim                 -0.620936
# policy_bind_day                0.028152
# policy_bind_month             -0.024643
# policy_bind_year               0.065022
# incident_day                   0.055443
# incident_month                 1.388336
# Automobile_Age                 0.054522
# policy_annual_premium          0.035964
# dtype: float64

# %% [markdown]
# - Features 'umbrella_limit','total_claim_amount' and 'vehicle_claim' are continous variable with skewnewss in the data. Also variable 'incident_month' is skewed but it is discrete in nature.
#
# - Usinf  yeo-johnson method to transform negatively skewed data.

# %%
# Considering the skewness in rage of  +0.5 and -0.5 for better prediction using yeo-johnson method
skew=['total_claim_amount','vehicle_claim']

# Importing Powertransformer
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# Transfroming skew data
df[skew] = scaler.fit_transform(df[skew].values)

# %% [markdown]
# <b>Skewness After Transformation<b>

# %%
df[skew].skew()
# Out:
# total_claim_amount   -0.508540
# vehicle_claim        -0.521805
# dtype: float64

# %% [markdown]
# - Skewness reduced to the border, thoughts for further skewness reduction, lead to proceed with this marginal skewnwss for vehicle claim

# %% [markdown]
# <b>Correlation<b>

# %%
df.corr()
# Out:
#                              months_as_customer       age  policy_state  \
# months_as_customer                     1.000000  0.922960     -0.007183
# age                                    0.922960  1.000000     -0.020012
# policy_state                          -0.007183 -0.020012      1.000000
# policy_deductable                      0.031041  0.032036      0.017612
# policy_annual_premium                 -0.003814  0.005330      0.015089
# umbrella_limit                         0.018213  0.013256     -0.010921
# insured_sex                            0.059644  0.073790     -0.018002
# insured_education_level               -0.000731  0.001647     -0.027173
# insured_occupation                     0.006925  0.014798     -0.025357
# insured_hobbies                       -0.089358 -0.079099     -0.039501
# insured_relationship                   0.071492  0.076129     -0.017060
# capital-gains                          0.007468 -0.004529      0.068619
# capital-loss                           0.023041  0.012860     -0.031926
# incident_type                         -0.016746 -0.026286      0.032373
# collision_type                        -0.023069 -0.022674      0.028545
# incident_severity                     -0.064094 -0.064396     -0.028353
# authorities_contacted                  0.013782  0.018441     -0.014647
# incident_state                         0.015811  0.012644      0.019456
# incident_city                         -0.006601 -0.006685     -0.002809
# incident_hour_of_the_day               0.066198  0.083720      0.021926
# number_of_vehicles_involved            0.011831  0.020391     -0.045514
# property_damage                        0.002374 -0.006900      0.006204
# bodily_injuries                       -0.007674 -0.012254      0.012097
# witnesses                              0.063574  0.056360      0.025838
# police_report_available                0.024521  0.019424      0.072142
# total_claim_amount                     0.059338  0.068448     -0.015056
# injury_claim                           0.065062  0.077149     -0.048188
# property_claim                         0.036660  0.062375     -0.006420
# vehicle_claim                          0.056360  0.059129     -0.006411
# auto_make                              0.049734  0.033757      0.010259
# auto_model                             0.005130  0.015322     -0.018008
# fraud_reported                         0.021285  0.013279      0.034587
# CSL_Personal                          -0.021855 -0.013323      0.001653
# CSL_Accidental                         0.007121  0.011258      0.029007
# policy_bind_day                        0.050824  0.053147     -0.000583
# policy_bind_month                      0.004207  0.014492      0.073692
# policy_bind_year                      -0.041914 -0.031709     -0.003045
# incident_day                          -0.010538 -0.005843      0.016049
# incident_month                         0.019242  0.018221      0.027889
# Automobile_Age                        -0.000869 -0.005594      0.001160
#
#                              policy_deductable  policy_annual_premium  \
# months_as_customer                    0.031041              -0.003814
# age                                   0.032036               0.005330
# policy_state                          0.017612               0.015089
# policy_deductable                     1.000000              -0.008300
# policy_annual_premium                -0.008300               1.000000
# umbrella_limit                        0.013471              -0.014107
# insured_sex                          -0.006977               0.041312
# insured_education_level               0.014101              -0.021400
# insured_occupation                   -0.053888               0.027827
# insured_hobbies                      -0.001923              -0.014226
# insured_relationship                 -0.019000               0.004417
# capital-gains                         0.031673              -0.006807
# capital-loss                         -0.019601               0.033133
# incident_type                        -0.032291               0.051606
# collision_type                       -0.033994               0.027938
# incident_severity                    -0.016363              -0.013911
# authorities_contacted                 0.002769              -0.054425
# incident_state                        0.000647               0.048647
# incident_city                        -0.047304               0.047771
# incident_hour_of_the_day              0.064732              -0.006448
# number_of_vehicles_involved           0.046331              -0.044544
# property_damage                       0.009067               0.087308
# bodily_injuries                      -0.037263               0.027837
# witnesses                             0.071709               0.003433
# police_report_available               0.030542               0.023249
# total_claim_amount                    0.024385              -0.000944
# injury_claim                          0.038459              -0.024119
# property_claim                        0.071031              -0.014073
# vehicle_claim                         0.004874               0.009194
# auto_make                            -0.028032               0.009311
# auto_model                           -0.002591              -0.038226
# fraud_reported                        0.015774              -0.012686
# CSL_Personal                          0.009912               0.032654
# CSL_Accidental                       -0.014554              -0.001868
# policy_bind_day                       0.013395              -0.032681
# policy_bind_month                    -0.054208              -0.031608
# policy_bind_year                     -0.054041               0.002433
# incident_day                         -0.018115               0.018671
# incident_month                       -0.010288               0.009544
# Automobile_Age                       -0.030569               0.042446
#
#                              umbrella_limit  insured_sex  \
# months_as_customer                 0.018213     0.059644
# age                                0.013256     0.073790
# policy_state                      -0.010921    -0.018002
# policy_deductable                  0.013471    -0.006977
# policy_annual_premium             -0.014107     0.041312
# umbrella_limit                     1.000000     0.018068
# insured_sex                        0.018068     1.000000
# insured_education_level           -0.030887     0.010068
# insured_occupation                 0.003973    -0.007440
# insured_hobbies                   -0.034098    -0.020928
# insured_relationship               0.095972     0.004488
# capital-gains                     -0.022753    -0.019824
# capital-loss                      -0.025844    -0.030319
# incident_type                      0.034951     0.009540
# collision_type                    -0.028851    -0.024737
# incident_severity                 -0.001297    -0.021242
# authorities_contacted              0.022396     0.019423
# incident_state                    -0.081479    -0.022522
# incident_city                      0.039685     0.009957
# incident_hour_of_the_day          -0.022571     0.012904
# number_of_vehicles_involved       -0.041298     0.018852
# property_damage                   -0.070757     0.030531
# bodily_injuries                    0.047719    -0.015199
# witnesses                         -0.001363     0.039343
# police_report_available           -0.037006     0.023181
# total_claim_amount                -0.047400    -0.016933
# injury_claim                      -0.046298     0.008472
# property_claim                    -0.021380    -0.008744
# vehicle_claim                     -0.048842    -0.023597
# auto_make                          0.012857     0.019996
# auto_model                         0.015360    -0.018657
# fraud_reported                     0.044729     0.020582
# CSL_Personal                       0.013504    -0.003405
# CSL_Accidental                     0.025418     0.071995
# policy_bind_day                   -0.030416     0.047690
# policy_bind_month                 -0.001072    -0.003125
# policy_bind_year                   0.049032    -0.031230
# incident_day                      -0.031948    -0.017208
# incident_month                     0.029210     0.036916
# Automobile_Age                    -0.027952     0.033336
#
#                              insured_education_level  insured_occupation  \
# months_as_customer                         -0.000731            0.006925
# age                                         0.001647            0.014798
# policy_state                               -0.027173           -0.025357
# policy_deductable                           0.014101           -0.053888
# policy_annual_premium                      -0.021400            0.027827
# umbrella_limit                             -0.030887            0.003973
# insured_sex                                 0.010068           -0.007440
# insured_education_level                     1.000000           -0.025394
# insured_occupation                         -0.025394            1.000000
# insured_hobbies                             0.025229           -0.010375
# insured_relationship                       -0.028673           -0.012135
# capital-gains                               0.044276            0.000409
# capital-loss                                0.037070           -0.016182
# incident_type                               0.005854            0.003755
# collision_type                              0.027863            0.011849
# incident_severity                          -0.010929           -0.000513
# authorities_contacted                      -0.015500           -0.000998
# incident_state                             -0.007821           -0.020759
# incident_city                              -0.022502            0.003112
# incident_hour_of_the_day                   -0.053983           -0.021657
# number_of_vehicles_involved                 0.003279           -0.015647
# property_damage                            -0.025850            0.003367
# bodily_injuries                            -0.017959           -0.000221
# witnesses                                   0.021747           -0.016435
# police_report_available                     0.039406           -0.012104
# total_claim_amount                          0.079642            0.008356
# injury_claim                                0.086600            0.024840
# property_claim                              0.062230            0.010040
# vehicle_claim                               0.072650            0.002591
# auto_make                                   0.060043            0.044331
# auto_model                                  0.042735            0.015152
# fraud_reported                              0.013116            0.000277
# CSL_Personal                                0.008337            0.016461
# CSL_Accidental                             -0.005150           -0.004376
# policy_bind_day                             0.018977            0.003377
# policy_bind_month                          -0.011963            0.020690
# policy_bind_year                            0.016874           -0.026467
# incident_day                               -0.051772           -0.020565
# incident_month                              0.069564            0.013989
# Automobile_Age                             -0.054438           -0.000915
#
#                              insured_hobbies  insured_relationship  \
# months_as_customer                 -0.089358              0.071492
# age                                -0.079099              0.076129
# policy_state                       -0.039501             -0.017060
# policy_deductable                  -0.001923             -0.019000
# policy_annual_premium              -0.014226              0.004417
# umbrella_limit                     -0.034098              0.095972
# insured_sex                        -0.020928              0.004488
# insured_education_level             0.025229             -0.028673
# insured_occupation                 -0.010375             -0.012135
# insured_hobbies                     1.000000             -0.095884
# insured_relationship               -0.095884              1.000000
# capital-gains                       0.054476             -0.020482
# capital-loss                       -0.030078             -0.062418
# incident_type                       0.012714              0.027740
# collision_type                     -0.003841             -0.012295
# incident_severity                  -0.024033              0.014774
# authorities_contacted              -0.028086             -0.000307
# incident_state                      0.079743             -0.063668
# incident_city                       0.019611             -0.005335
# incident_hour_of_the_day            0.017177              0.005602
# number_of_vehicles_involved         0.007490             -0.044342
# property_damage                     0.030054             -0.040665
# bodily_injuries                     0.026890              0.001363
# witnesses                          -0.036967             -0.001631
# police_report_available            -0.051683             -0.027735
# total_claim_amount                 -0.001466              0.004031
# injury_claim                        0.031374              0.031088
# property_claim                      0.010616              0.005691
# vehicle_claim                      -0.013752             -0.004344
# auto_make                          -0.000984             -0.030718
# auto_model                          0.034818              0.057003
# fraud_reported                     -0.048181              0.026575
# CSL_Personal                       -0.003695             -0.034603
# CSL_Accidental                      0.035959             -0.037223
# policy_bind_day                     0.035344              0.008887
# policy_bind_month                  -0.003806              0.039564
# policy_bind_year                   -0.020370             -0.006341
# incident_day                        0.016051             -0.078348
# incident_month                     -0.001147              0.045237
# Automobile_Age                      0.018361              0.020051
#
#                              capital-gains  capital-loss  incident_type  \
# months_as_customer                0.007468      0.023041      -0.016746
# age                              -0.004529      0.012860      -0.026286
# policy_state                      0.068619     -0.031926       0.032373
# policy_deductable                 0.031673     -0.019601      -0.032291
# policy_annual_premium            -0.006807      0.033133       0.051606
# umbrella_limit                   -0.022753     -0.025844       0.034951
# insured_sex                      -0.019824     -0.030319       0.009540
# insured_education_level           0.044276      0.037070       0.005854
# insured_occupation                0.000409     -0.016182       0.003755
# insured_hobbies                   0.054476     -0.030078       0.012714
# insured_relationship             -0.020482     -0.062418       0.027740
# capital-gains                     1.000000     -0.047387      -0.042178
# capital-loss                     -0.047387      1.000000       0.017490
# incident_type                    -0.042178      0.017490       1.000000
# collision_type                    0.013011      0.012638      -0.324581
# incident_severity                -0.010312     -0.011845       0.156929
# authorities_contacted            -0.046192      0.012790       0.095919
# incident_state                    0.017182     -0.053073       0.035372
# incident_city                    -0.035961     -0.035095       0.024138
# incident_hour_of_the_day         -0.016288     -0.029339      -0.134586
# number_of_vehicles_involved       0.057932     -0.007438      -0.894148
# property_damage                   0.025308      0.008006       0.021613
# bodily_injuries                   0.047421     -0.031480      -0.011155
# witnesses                        -0.018701     -0.037671      -0.007484
# police_report_available          -0.010237     -0.027238       0.018991
# total_claim_amount                0.010549     -0.035532      -0.266770
# injury_claim                      0.021430     -0.044049      -0.222032
# property_claim                   -0.009262     -0.021848      -0.220058
# vehicle_claim                     0.011751     -0.032407      -0.260443
# auto_make                         0.057197     -0.051431      -0.039905
# auto_model                        0.049813     -0.040877      -0.041414
# fraud_reported                   -0.014993     -0.017617      -0.040893
# CSL_Personal                      0.009786     -0.035589       0.005180
# CSL_Accidental                   -0.004870      0.010440       0.004640
# policy_bind_day                   0.001224     -0.030852      -0.006095
# policy_bind_month                -0.008909      0.003280       0.037715
# policy_bind_year                  0.039978     -0.026457      -0.048389
# incident_day                      0.017699     -0.018464       0.013663
# incident_month                    0.037077      0.030991      -0.037530
# Automobile_Age                   -0.029903      0.062780       0.044207
#
#                              collision_type  incident_severity  \
# months_as_customer                -0.023069          -0.064094
# age                               -0.022674          -0.064396
# policy_state                       0.028545          -0.028353
# policy_deductable                 -0.033994          -0.016363
# policy_annual_premium              0.027938          -0.013911
# umbrella_limit                    -0.028851          -0.001297
# insured_sex                       -0.024737          -0.021242
# insured_education_level            0.027863          -0.010929
# insured_occupation                 0.011849          -0.000513
# insured_hobbies                   -0.003841          -0.024033
# insured_relationship              -0.012295           0.014774
# capital-gains                      0.013011          -0.010312
# capital-loss                       0.012638          -0.011845
# incident_type                     -0.324581           0.156929
# collision_type                     1.000000          -0.304634
# incident_severity                 -0.304634           1.000000
# authorities_contacted             -0.137018           0.164854
# incident_state                    -0.021195           0.065112
# incident_city                      0.019026          -0.018072
# incident_hour_of_the_day           0.211243          -0.075029
# number_of_vehicles_involved        0.332153          -0.166737
# property_damage                    0.003525          -0.012140
# bodily_injuries                   -0.010192          -0.018126
# witnesses                         -0.038464          -0.005564
# police_report_available            0.033236           0.019344
# total_claim_amount                 0.578509          -0.360119
# injury_claim                       0.442074          -0.273482
# property_claim                     0.452511          -0.303125
# vehicle_claim                      0.581404          -0.356637
# auto_make                         -0.018323          -0.005527
# auto_model                         0.039809          -0.049808
# fraud_reported                     0.107403          -0.401808
# CSL_Personal                      -0.027089           0.017195
# CSL_Accidental                    -0.014329           0.011673
# policy_bind_day                    0.005680          -0.037886
# policy_bind_month                 -0.011622          -0.036582
# policy_bind_year                   0.046790           0.005476
# incident_day                       0.003846           0.019190
# incident_month                     0.032985          -0.013664
# Automobile_Age                     0.022738           0.009588
#
#                              authorities_contacted  incident_state  \
# months_as_customer                        0.013782        0.015811
# age                                       0.018441        0.012644
# policy_state                             -0.014647        0.019456
# policy_deductable                         0.002769        0.000647
# policy_annual_premium                    -0.054425        0.048647
# umbrella_limit                            0.022396       -0.081479
# insured_sex                               0.019423       -0.022522
# insured_education_level                  -0.015500       -0.007821
# insured_occupation                       -0.000998       -0.020759
# insured_hobbies                          -0.028086        0.079743
# insured_relationship                     -0.000307       -0.063668
# capital-gains                            -0.046192        0.017182
# capital-loss                              0.012790       -0.053073
# incident_type                             0.095919        0.035372
# collision_type                           -0.137018       -0.021195
# incident_severity                         0.164854        0.065112
# authorities_contacted                     1.000000        0.024742
# incident_state                            0.024742        1.000000
# incident_city                            -0.006286        0.017458
# incident_hour_of_the_day                 -0.058827       -0.033427
# number_of_vehicles_involved              -0.077550       -0.031451
# property_damage                          -0.006706       -0.027884
# bodily_injuries                           0.038572       -0.003194
# witnesses                                -0.001834        0.011652
# police_report_available                   0.032029        0.016275
# total_claim_amount                       -0.167270       -0.037109
# injury_claim                             -0.145290       -0.013219
# property_claim                           -0.120224       -0.021514
# vehicle_claim                            -0.166711       -0.043901
# auto_make                                -0.027299        0.073847
# auto_model                                0.018781       -0.042899
# fraud_reported                           -0.043636       -0.052027
# CSL_Personal                              0.051030        0.035804
# CSL_Accidental                            0.010505        0.005663
# policy_bind_day                          -0.036420        0.040592
# policy_bind_month                        -0.048840        0.001721
# policy_bind_year                         -0.032755       -0.028406
# incident_day                             -0.014321        0.018364
# incident_month                            0.006895       -0.027527
# Automobile_Age                           -0.078044        0.016908
#
#                              incident_city  incident_hour_of_the_day  \
# months_as_customer               -0.006601                  0.066198
# age                              -0.006685                  0.083720
# policy_state                     -0.002809                  0.021926
# policy_deductable                -0.047304                  0.064732
# policy_annual_premium             0.047771                 -0.006448
# umbrella_limit                    0.039685                 -0.022571
# insured_sex                       0.009957                  0.012904
# insured_education_level          -0.022502                 -0.053983
# insured_occupation                0.003112                 -0.021657
# insured_hobbies                   0.019611                  0.017177
# insured_relationship             -0.005335                  0.005602
# capital-gains                    -0.035961                 -0.016288
# capital-loss                     -0.035095                 -0.029339
# incident_type                     0.024138                 -0.134586
# collision_type                    0.019026                  0.211243
# incident_severity                -0.018072                 -0.075029
# authorities_contacted            -0.006286                 -0.058827
# incident_state                    0.017458                 -0.033427
# incident_city                     1.000000                  0.014158
# incident_hour_of_the_day          0.014158                  1.000000
# number_of_vehicles_involved      -0.011232                  0.120599
# property_damage                   0.027177                  0.062259
# bodily_injuries                   0.042923                 -0.033120
# witnesses                         0.008201                  0.006843
# police_report_available           0.020185                  0.040311
# total_claim_amount                0.040296                  0.216020
# injury_claim                      0.043915                  0.173753
# property_claim                    0.037697                  0.176317
# vehicle_claim                     0.034817                  0.212482
# auto_make                         0.005561                 -0.007946
# auto_model                        0.024292                 -0.059031
# fraud_reported                   -0.039434                  0.004326
# CSL_Personal                      0.014380                  0.003918
# CSL_Accidental                   -0.023156                  0.006180
# policy_bind_day                   0.009023                 -0.005947
# policy_bind_month                 0.070199                 -0.001737
# policy_bind_year                 -0.009456                  0.039484
# incident_day                     -0.047271                 -0.030009
# incident_month                    0.036482                  0.045796
# Automobile_Age                   -0.062385                 -0.016597
#
#                              number_of_vehicles_involved  property_damage  \
# months_as_customer                              0.011831         0.002374
# age                                             0.020391        -0.006900
# policy_state                                   -0.045514         0.006204
# policy_deductable                               0.046331         0.009067
# policy_annual_premium                          -0.044544         0.087308
# umbrella_limit                                 -0.041298        -0.070757
# insured_sex                                     0.018852         0.030531
# insured_education_level                         0.003279        -0.025850
# insured_occupation                             -0.015647         0.003367
# insured_hobbies                                 0.007490         0.030054
# insured_relationship                           -0.044342        -0.040665
# capital-gains                                   0.057932         0.025308
# capital-loss                                   -0.007438         0.008006
# incident_type                                  -0.894148         0.021613
# collision_type                                  0.332153         0.003525
# incident_severity                              -0.166737        -0.012140
# authorities_contacted                          -0.077550        -0.006706
# incident_state                                 -0.031451        -0.027884
# incident_city                                  -0.011232         0.027177
# incident_hour_of_the_day                        0.120599         0.062259
# number_of_vehicles_involved                     1.000000        -0.012248
# property_damage                                -0.012248         1.000000
# bodily_injuries                                 0.013094        -0.004781
# witnesses                                      -0.014410        -0.027108
# police_report_available                        -0.008634        -0.028442
# total_claim_amount                              0.264344         0.042374
# injury_claim                                    0.221080         0.046708
# property_claim                                  0.218462         0.029919
# vehicle_claim                                   0.257673         0.039187
# auto_make                                       0.017986        -0.016920
# auto_model                                      0.036555        -0.047120
# fraud_reported                                  0.043535        -0.028548
# CSL_Personal                                   -0.014658        -0.020171
# CSL_Accidental                                 -0.004455         0.002830
# policy_bind_day                                 0.003681        -0.008999
# policy_bind_month                              -0.042271         0.023951
# policy_bind_year                                0.023556         0.013179
# incident_day                                   -0.021352         0.007042
# incident_month                                  0.030693        -0.002183
# Automobile_Age                                 -0.028295         0.043408
#
#                              bodily_injuries  witnesses  \
# months_as_customer                 -0.007674   0.063574
# age                                -0.012254   0.056360
# policy_state                        0.012097   0.025838
# policy_deductable                  -0.037263   0.071709
# policy_annual_premium               0.027837   0.003433
# umbrella_limit                      0.047719  -0.001363
# insured_sex                        -0.015199   0.039343
# insured_education_level            -0.017959   0.021747
# insured_occupation                 -0.000221  -0.016435
# insured_hobbies                     0.026890  -0.036967
# insured_relationship                0.001363  -0.001631
# capital-gains                       0.047421  -0.018701
# capital-loss                       -0.031480  -0.037671
# incident_type                      -0.011155  -0.007484
# collision_type                     -0.010192  -0.038464
# incident_severity                  -0.018126  -0.005564
# authorities_contacted               0.038572  -0.001834
# incident_state                     -0.003194   0.011652
# incident_city                       0.042923   0.008201
# incident_hour_of_the_day           -0.033120   0.006843
# number_of_vehicles_involved         0.013094  -0.014410
# property_damage                    -0.004781  -0.027108
# bodily_injuries                     1.000000   0.001083
# witnesses                           0.001083   1.000000
# police_report_available             0.012276   0.044892
# total_claim_amount                  0.045814  -0.013857
# injury_claim                        0.044349  -0.025951
# property_claim                      0.036189   0.048616
# vehicle_claim                       0.042858  -0.025670
# auto_make                           0.029512   0.005529
# auto_model                          0.025879  -0.005816
# fraud_reported                      0.039184   0.049974
# CSL_Personal                        0.001385   0.071361
# CSL_Accidental                     -0.020053  -0.012073
# policy_bind_day                    -0.046463   0.002109
# policy_bind_month                  -0.031546  -0.012699
# policy_bind_year                    0.025891   0.051345
# incident_day                       -0.027563   0.018054
# incident_month                      0.046969  -0.027943
# Automobile_Age                      0.016984  -0.047636
#
#                              police_report_available  total_claim_amount  \
# months_as_customer                          0.024521            0.059338
# age                                         0.019424            0.068448
# policy_state                                0.072142           -0.015056
# policy_deductable                           0.030542            0.024385
# policy_annual_premium                       0.023249           -0.000944
# umbrella_limit                             -0.037006           -0.047400
# insured_sex                                 0.023181           -0.016933
# insured_education_level                     0.039406            0.079642
# insured_occupation                         -0.012104            0.008356
# insured_hobbies                            -0.051683           -0.001466
# insured_relationship                       -0.027735            0.004031
# capital-gains                              -0.010237            0.010549
# capital-loss                               -0.027238           -0.035532
# incident_type                               0.018991           -0.266770
# collision_type                              0.033236            0.578509
# incident_severity                           0.019344           -0.360119
# authorities_contacted                       0.032029           -0.167270
# incident_state                              0.016275           -0.037109
# incident_city                               0.020185            0.040296
# incident_hour_of_the_day                    0.040311            0.216020
# number_of_vehicles_involved                -0.008634            0.264344
# property_damage                            -0.028442            0.042374
# bodily_injuries                             0.012276            0.045814
# witnesses                                   0.044892           -0.013857
# police_report_available                     1.000000            0.003609
# total_claim_amount                          0.003609            1.000000
# injury_claim                               -0.006468            0.807017
# property_claim                             -0.004705            0.812584
# vehicle_claim                               0.008286            0.981046
# auto_make                                   0.028399           -0.053016
# auto_model                                 -0.027773            0.044617
# fraud_reported                             -0.023824            0.162420
# CSL_Personal                               -0.005171           -0.053435
# CSL_Accidental                              0.078901           -0.019772
# policy_bind_day                            -0.039466           -0.014298
# policy_bind_month                          -0.025858            0.060147
# policy_bind_year                           -0.007927           -0.001971
# incident_day                                0.028873           -0.039623
# incident_month                             -0.027239            0.053928
# Automobile_Age                              0.015064            0.040099
#
#                              injury_claim  property_claim  vehicle_claim  \
# months_as_customer               0.065062        0.036660       0.056360
# age                              0.077149        0.062375       0.059129
# policy_state                    -0.048188       -0.006420      -0.006411
# policy_deductable                0.038459        0.071031       0.004874
# policy_annual_premium           -0.024119       -0.014073       0.009194
# umbrella_limit                  -0.046298       -0.021380      -0.048842
# insured_sex                      0.008472       -0.008744      -0.023597
# insured_education_level          0.086600        0.062230       0.072650
# insured_occupation               0.024840        0.010040       0.002591
# insured_hobbies                  0.031374        0.010616      -0.013752
# insured_relationship             0.031088        0.005691      -0.004344
# capital-gains                    0.021430       -0.009262       0.011751
# capital-loss                    -0.044049       -0.021848      -0.032407
# incident_type                   -0.222032       -0.220058      -0.260443
# collision_type                   0.442074        0.452511       0.581404
# incident_severity               -0.273482       -0.303125      -0.356637
# authorities_contacted           -0.145290       -0.120224      -0.166711
# incident_state                  -0.013219       -0.021514      -0.043901
# incident_city                    0.043915        0.037697       0.034817
# incident_hour_of_the_day         0.173753        0.176317       0.212482
# number_of_vehicles_involved      0.221080        0.218462       0.257673
# property_damage                  0.046708        0.029919       0.039187
# bodily_injuries                  0.044349        0.036189       0.042858
# witnesses                       -0.025951        0.048616      -0.025670
# police_report_available         -0.006468       -0.004705       0.008286
# total_claim_amount               0.807017        0.812584       0.981046
# injury_claim                     1.000000        0.567714       0.720168
# property_claim                   0.567714        1.000000       0.730148
# vehicle_claim                    0.720168        0.730148       1.000000
# auto_make                       -0.031745       -0.043108      -0.054549
# auto_model                       0.042930        0.054570       0.037127
# fraud_reported                   0.088812        0.139101       0.169284
# CSL_Personal                    -0.080098       -0.042876      -0.042728
# CSL_Accidental                   0.000055       -0.015800      -0.023797
# policy_bind_day                  0.002086       -0.014316      -0.017020
# policy_bind_month                0.020589        0.056362       0.064575
# policy_bind_year                 0.000805       -0.002393      -0.002153
# incident_day                    -0.023289       -0.015431      -0.045824
# incident_month                   0.015556        0.042797       0.061002
# Automobile_Age                   0.018872        0.018923       0.046500
#
#                              auto_make  auto_model  fraud_reported  \
# months_as_customer            0.049734    0.005130        0.021285
# age                           0.033757    0.015322        0.013279
# policy_state                  0.010259   -0.018008        0.034587
# policy_deductable            -0.028032   -0.002591        0.015774
# policy_annual_premium         0.009311   -0.038226       -0.012686
# umbrella_limit                0.012857    0.015360        0.044729
# insured_sex                   0.019996   -0.018657        0.020582
# insured_education_level       0.060043    0.042735        0.013116
# insured_occupation            0.044331    0.015152        0.000277
# insured_hobbies              -0.000984    0.034818       -0.048181
# insured_relationship         -0.030718    0.057003        0.026575
# capital-gains                 0.057197    0.049813       -0.014993
# capital-loss                 -0.051431   -0.040877       -0.017617
# incident_type                -0.039905   -0.041414       -0.040893
# collision_type               -0.018323    0.039809        0.107403
# incident_severity            -0.005527   -0.049808       -0.401808
# authorities_contacted        -0.027299    0.018781       -0.043636
# incident_state                0.073847   -0.042899       -0.052027
# incident_city                 0.005561    0.024292       -0.039434
# incident_hour_of_the_day     -0.007946   -0.059031        0.004326
# number_of_vehicles_involved   0.017986    0.036555        0.043535
# property_damage              -0.016920   -0.047120       -0.028548
# bodily_injuries               0.029512    0.025879        0.039184
# witnesses                     0.005529   -0.005816        0.049974
# police_report_available       0.028399   -0.027773       -0.023824
# total_claim_amount           -0.053016    0.044617        0.162420
# injury_claim                 -0.031745    0.042930        0.088812
# property_claim               -0.043108    0.054570        0.139101
# vehicle_claim                -0.054549    0.037127        0.169284
# auto_make                     1.000000   -0.173016       -0.032206
# auto_model                   -0.173016    1.000000       -0.002825
# fraud_reported               -0.032206   -0.002825        1.000000
# CSL_Personal                 -0.009395    0.042905       -0.032509
# CSL_Accidental               -0.025250   -0.001119        0.042864
# policy_bind_day              -0.010551   -0.005126        0.063705
# policy_bind_month            -0.041099   -0.007687       -0.032606
# policy_bind_year             -0.004028    0.029770        0.003317
# incident_day                  0.049668   -0.043141       -0.058330
# incident_month               -0.031146    0.028307        0.024143
# Automobile_Age                0.003440   -0.038604       -0.001152
#
#                              CSL_Personal  CSL_Accidental  policy_bind_day  \
# months_as_customer              -0.021855        0.007121         0.050824
# age                             -0.013323        0.011258         0.053147
# policy_state                     0.001653        0.029007        -0.000583
# policy_deductable                0.009912       -0.014554         0.013395
# policy_annual_premium            0.032654       -0.001868        -0.032681
# umbrella_limit                   0.013504        0.025418        -0.030416
# insured_sex                     -0.003405        0.071995         0.047690
# insured_education_level          0.008337       -0.005150         0.018977
# insured_occupation               0.016461       -0.004376         0.003377
# insured_hobbies                 -0.003695        0.035959         0.035344
# insured_relationship            -0.034603       -0.037223         0.008887
# capital-gains                    0.009786       -0.004870         0.001224
# capital-loss                    -0.035589        0.010440        -0.030852
# incident_type                    0.005180        0.004640        -0.006095
# collision_type                  -0.027089       -0.014329         0.005680
# incident_severity                0.017195        0.011673        -0.037886
# authorities_contacted            0.051030        0.010505        -0.036420
# incident_state                   0.035804        0.005663         0.040592
# incident_city                    0.014380       -0.023156         0.009023
# incident_hour_of_the_day         0.003918        0.006180        -0.005947
# number_of_vehicles_involved     -0.014658       -0.004455         0.003681
# property_damage                 -0.020171        0.002830        -0.008999
# bodily_injuries                  0.001385       -0.020053        -0.046463
# witnesses                        0.071361       -0.012073         0.002109
# police_report_available         -0.005171        0.078901        -0.039466
# total_claim_amount              -0.053435       -0.019772        -0.014298
# injury_claim                    -0.080098        0.000055         0.002086
# property_claim                  -0.042876       -0.015800        -0.014316
# vehicle_claim                   -0.042728       -0.023797        -0.017020
# auto_make                       -0.009395       -0.025250        -0.010551
# auto_model                       0.042905       -0.001119        -0.005126
# fraud_reported                  -0.032509        0.042864         0.063705
# CSL_Personal                     1.000000       -0.456766         0.013568
# CSL_Accidental                  -0.456766        1.000000         0.014486
# policy_bind_day                  0.013568        0.014486         1.000000
# policy_bind_month               -0.041283        0.032044         0.042319
# policy_bind_year                -0.019409       -0.000831         0.001074
# incident_day                    -0.002278        0.031458         0.025739
# incident_month                  -0.010904       -0.030397         0.004014
# Automobile_Age                   0.030370       -0.029835        -0.021052
#
#                              policy_bind_month  policy_bind_year  \
# months_as_customer                    0.004207         -0.041914
# age                                   0.014492         -0.031709
# policy_state                          0.073692         -0.003045
# policy_deductable                    -0.054208         -0.054041
# policy_annual_premium                -0.031608          0.002433
# umbrella_limit                       -0.001072          0.049032
# insured_sex                          -0.003125         -0.031230
# insured_education_level              -0.011963          0.016874
# insured_occupation                    0.020690         -0.026467
# insured_hobbies                      -0.003806         -0.020370
# insured_relationship                  0.039564         -0.006341
# capital-gains                        -0.008909          0.039978
# capital-loss                          0.003280         -0.026457
# incident_type                         0.037715         -0.048389
# collision_type                       -0.011622          0.046790
# incident_severity                    -0.036582          0.005476
# authorities_contacted                -0.048840         -0.032755
# incident_state                        0.001721         -0.028406
# incident_city                         0.070199         -0.009456
# incident_hour_of_the_day             -0.001737          0.039484
# number_of_vehicles_involved          -0.042271          0.023556
# property_damage                       0.023951          0.013179
# bodily_injuries                      -0.031546          0.025891
# witnesses                            -0.012699          0.051345
# police_report_available              -0.025858         -0.007927
# total_claim_amount                    0.060147         -0.001971
# injury_claim                          0.020589          0.000805
# property_claim                        0.056362         -0.002393
# vehicle_claim                         0.064575         -0.002153
# auto_make                            -0.041099         -0.004028
# auto_model                           -0.007687          0.029770
# fraud_reported                       -0.032606          0.003317
# CSL_Personal                         -0.041283         -0.019409
# CSL_Accidental                        0.032044         -0.000831
# policy_bind_day                       0.042319          0.001074
# policy_bind_month                     1.000000         -0.004808
# policy_bind_year                     -0.004808          1.000000
# incident_day                         -0.040712          0.055181
# incident_month                        0.015708         -0.064748
# Automobile_Age                       -0.001076         -0.016244
#
#                              incident_day  incident_month  Automobile_Age
# months_as_customer              -0.010538        0.019242       -0.000869
# age                             -0.005843        0.018221       -0.005594
# policy_state                     0.016049        0.027889        0.001160
# policy_deductable               -0.018115       -0.010288       -0.030569
# policy_annual_premium            0.018671        0.009544        0.042446
# umbrella_limit                  -0.031948        0.029210       -0.027952
# insured_sex                     -0.017208        0.036916        0.033336
# insured_education_level         -0.051772        0.069564       -0.054438
# insured_occupation              -0.020565        0.013989       -0.000915
# insured_hobbies                  0.016051       -0.001147        0.018361
# insured_relationship            -0.078348        0.045237        0.020051
# capital-gains                    0.017699        0.037077       -0.029903
# capital-loss                    -0.018464        0.030991        0.062780
# incident_type                    0.013663       -0.037530        0.044207
# collision_type                   0.003846        0.032985        0.022738
# incident_severity                0.019190       -0.013664        0.009588
# authorities_contacted           -0.014321        0.006895       -0.078044
# incident_state                   0.018364       -0.027527        0.016908
# incident_city                   -0.047271        0.036482       -0.062385
# incident_hour_of_the_day        -0.030009        0.045796       -0.016597
# number_of_vehicles_involved     -0.021352        0.030693       -0.028295
# property_damage                  0.007042       -0.002183        0.043408
# bodily_injuries                 -0.027563        0.046969        0.016984
# witnesses                        0.018054       -0.027943       -0.047636
# police_report_available          0.028873       -0.027239        0.015064
# total_claim_amount              -0.039623        0.053928        0.040099
# injury_claim                    -0.023289        0.015556        0.018872
# property_claim                  -0.015431        0.042797        0.018923
# vehicle_claim                   -0.045824        0.061002        0.046500
# auto_make                        0.049668       -0.031146        0.003440
# auto_model                      -0.043141        0.028307       -0.038604
# fraud_reported                  -0.058330        0.024143       -0.001152
# CSL_Personal                    -0.002278       -0.010904        0.030370
# CSL_Accidental                   0.031458       -0.030397       -0.029835
# policy_bind_day                  0.025739        0.004014       -0.021052
# policy_bind_month               -0.040712        0.015708       -0.001076
# policy_bind_year                 0.055181       -0.064748       -0.016244
# incident_day                     1.000000       -0.666135       -0.012973
# incident_month                  -0.666135        1.000000        0.031696
# Automobile_Age                  -0.012973        0.031696        1.000000

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', cmap="gist_stern")
plt.show()

# %%
plt.figure(figsize=(22,10))
df.corr()['fraud_reported'].sort_values(ascending=False).drop(['fraud_reported']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=14,fontweight='bold')
plt.ylabel('Target',fontsize=14,fontweight='bold')
plt.title('Correlation of features with Target Variable Fraud_reported',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# - incident_severity is correlated with target variable with correlation of -0.4,  but okay. Other variable are poorly correlated with target variable.
# - injury_claim,property_claim,vehicle_claim are highly correlated with each other.
# - incident_hour_of_the_day is highly negative correlated with incident type
# - Number of Vehiocles involved and incident type are also highly correlated

# %% [markdown]
# <b>Balancing the Imbalanced Target Feature<b>

# %%
df.fraud_reported.value_counts()
# Out:
# 0    740
# 1    240
# Name: fraud_reported, dtype: int64

# %%
# Splitting data in target and dependent feature
X = df.drop(['fraud_reported'], axis =1)
Y = df['fraud_reported']

# %%
# Oversampleing using SMOTE Technique
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
Y.value_counts()
# Out:
# 1    740
# 0    740
# Name: fraud_reported, dtype: int64

# %% [markdown]
# - Imbalancing Target variable problem solved

# %% [markdown]
# <b>Standard Scaler<b>

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# <b> MultiColinearity Using Varience Inflation Factor<b>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(X_scale,i) for i in range(len(X.columns))]
vif["Features"] = X.columns
vif
# Out:
#       VIF values                     Features
# 0       7.405227           months_as_customer
# 1       7.389212                          age
# 2       1.063017                 policy_state
# 3       1.056626            policy_deductable
# 4       1.041774        policy_annual_premium
# 5       1.063163               umbrella_limit
# 6       1.096245                  insured_sex
# 7       1.060471      insured_education_level
# 8       1.032971           insured_occupation
# 9       1.076981              insured_hobbies
# 10      1.062507         insured_relationship
# 11      1.059814                capital-gains
# 12      1.059676                 capital-loss
# 13      3.879544                incident_type
# 14      1.754132               collision_type
# 15      1.370484            incident_severity
# 16      1.120371        authorities_contacted
# 17      1.077398               incident_state
# 18      1.079172                incident_city
# 19      1.125042     incident_hour_of_the_day
# 20      3.808987  number_of_vehicles_involved
# 21      1.081854              property_damage
# 22      1.070885              bodily_injuries
# 23      1.081095                    witnesses
# 24      1.095763      police_report_available
# 25  46481.539411           total_claim_amount
# 26   1856.965385                 injury_claim
# 27   1839.915451               property_claim
# 28  23132.595554                vehicle_claim
# 29      1.089489                    auto_make
# 30      1.089663                   auto_model
# 31      1.236888                 CSL_Personal
# 32      1.224800               CSL_Accidental
# 33      1.036569              policy_bind_day
# 34      1.063514            policy_bind_month
# 35      1.045725             policy_bind_year
# 36      1.815323                 incident_day
# 37      1.818153               incident_month
# 38      1.076764               Automobile_Age

# %% [markdown]
# - some features are having high colinearity, but wee saw only a few veriables are having high correlation, lets do a PCA

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(X_scale)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid(b=True)

# %% [markdown]
# - 28 Principle components are Contributing 90% of the data, lets removes the rest of the features which has less contributions

# %%
pca_new = PCA(n_components=28)
x_new = pca_new.fit_transform(X_scale)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(28))

# %% [markdown]
# #### ML Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1036, 28)
# Training target vector size: (1036,)
# Test feature matrix size: (444, 28)
# Test target vector size: (444,)

# %% [markdown]
# <b>Best Random State<b>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,250):
    X_train,X_test,Y_train,Y_test = train_test_split(principle_x,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.8085585585585585 on Random_state 213

# %%
X_train, X_test, Y_train, Y_test = train_test_split(principle_x, Y, random_state=213, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.8085585585585585
#
#
# Confusion matrix of Logistics Regression :
#  [[162  46]
#  [ 39 197]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       208
#            1       0.81      0.83      0.82       236
#
#     accuracy                           0.81       444
#    macro avg       0.81      0.81      0.81       444
# weighted avg       0.81      0.81      0.81       444

# %% [markdown]
# <b>Optimal Value for KNN<b>

# %%
from sklearn import neighbors
from math import sqrt
from sklearn.metrics import mean_squared_error
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = neighbors.KNeighborsClassifier(n_neighbors = K)

    model.fit(X_train,Y_train)  #fit the model
    y_pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(Y_test,y_pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.4527195102433238
# RMSE value for k=  2 is: 0.4137283784938751
# RMSE value for k=  3 is: 0.4793012932694108
# RMSE value for k=  4 is: 0.4625623892665334
# RMSE value for k=  5 is: 0.5263335701121742
# RMSE value for k=  6 is: 0.4909083325744135
# RMSE value for k=  7 is: 0.5
# RMSE value for k=  8 is: 0.497742652128334
# RMSE value for k=  9 is: 0.5198752449100363
# RMSE value for k=  10 is: 0.5
# RMSE value for k=  11 is: 0.5348233690070359
# RMSE value for k=  12 is: 0.5220368976638744
# RMSE value for k=  13 is: 0.5411033106466757
# RMSE value for k=  14 is: 0.5241896362718123
# RMSE value for k=  15 is: 0.5595203866375765
# RMSE value for k=  16 is: 0.5411033106466757
# RMSE value for k=  17 is: 0.5595203866375765
# RMSE value for k=  18 is: 0.5411033106466757
# RMSE value for k=  19 is: 0.5615294429638711
# RMSE value for k=  20 is: 0.5431804903022982

# %%
#plotting the rmse values against k values -
plt.figure(figsize = (8,6))
plt.plot(range(20), rmse_val, color='blue', linestyle='dashed', marker='o', markerfacecolor='green', markersize=10)

# %% [markdown]
# - At k=2, we get the minimum RMSE value which approximately 0.0.4137283784938751, and shoots up on further increasing the k value, k=2

# %% [markdown]
# <b>Applying other classification algorithm<b>

# %%
model=[ LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]
        
for m in model:
    m.fit(X_train,Y_train)
    y_pred=m.predict(X_test)
    print('\033[1m'+'Classification ML Algorithm Evaluation Matrix',m,'is' +'\033[0m')
    print('\n')
    print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Confusion matrix :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
    print('\n')
    print('\033[1m'+'Classification Report :'+'\033[0m \n',classification_report(Y_test, y_pred))
    print('\n')
    print('------------------------------------------------------------------------------------------------------------------')
# Out:
# Classification ML Algorithm Evaluation Matrix LogisticRegression() is
#
#
# Accuracy Score :
#  0.8085585585585585
#
#
# Confusion matrix :
#  [[162  46]
#  [ 39 197]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.78      0.79       208
#            1       0.81      0.83      0.82       236
#
#     accuracy                           0.81       444
#    macro avg       0.81      0.81      0.81       444
# weighted avg       0.81      0.81      0.81       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------
# Classification ML Algorithm Evaluation Matrix SVC() is
#
#
# Accuracy Score :
#  0.8355855855855856
#
#
# Confusion matrix :
#  [[181  27]
#  [ 46 190]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83       208
#            1       0.88      0.81      0.84       236
#
#     accuracy                           0.84       444
#    macro avg       0.84      0.84      0.84       444
# weighted avg       0.84      0.84      0.84       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------
# Classification ML Algorithm Evaluation Matrix GaussianNB() is
#
#
# Accuracy Score :
#  0.8153153153153153
#
#
# Confusion matrix :
#  [[169  39]
#  [ 43 193]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.80      0.81      0.80       208
#            1       0.83      0.82      0.82       236
#
#     accuracy                           0.82       444
#    macro avg       0.81      0.82      0.81       444
# weighted avg       0.82      0.82      0.82       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------
# Classification ML Algorithm Evaluation Matrix DecisionTreeClassifier() is
#
#
# Accuracy Score :
#  0.6869369369369369
#
#
# Confusion matrix :
#  [[127  81]
#  [ 58 178]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.69      0.61      0.65       208
#            1       0.69      0.75      0.72       236
#
#     accuracy                           0.69       444
#    macro avg       0.69      0.68      0.68       444
# weighted avg       0.69      0.69      0.69       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------
# Classification ML Algorithm Evaluation Matrix KNeighborsClassifier(n_neighbors=3) is
#
#
# Accuracy Score :
#  0.7702702702702703
#
#
# Confusion matrix :
#  [[112  96]
#  [  6 230]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.95      0.54      0.69       208
#            1       0.71      0.97      0.82       236
#
#     accuracy                           0.77       444
#    macro avg       0.83      0.76      0.75       444
# weighted avg       0.82      0.77      0.76       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------
# Classification ML Algorithm Evaluation Matrix RandomForestClassifier() is
#
#
# Accuracy Score :
#  0.8130630630630631
#
#
# Confusion matrix :
#  [[180  28]
#  [ 55 181]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.77      0.87      0.81       208
#            1       0.87      0.77      0.81       236
#
#     accuracy                           0.81       444
#    macro avg       0.82      0.82      0.81       444
# weighted avg       0.82      0.81      0.81       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------
# Classification ML Algorithm Evaluation Matrix ExtraTreesClassifier() is
#
#
# Accuracy Score :
#  0.8445945945945946
#
#
# Confusion matrix :
#  [[181  27]
#  [ 42 194]]
#
#
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84       208
#            1       0.88      0.82      0.85       236
#
#     accuracy                           0.84       444
#    macro avg       0.84      0.85      0.84       444
# weighted avg       0.85      0.84      0.84       444
#
#
#
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Cross Validation Score<b>

# %%
from sklearn.model_selection import cross_val_score
model=[LogisticRegression(),
        SVC(),
        GaussianNB(),
        DecisionTreeClassifier(),
        KNeighborsClassifier(n_neighbors = 3),
        RandomForestClassifier(),
        ExtraTreesClassifier()]

for m in model:
    score = cross_val_score(m, principle_x, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score', m, ':'+'\033[0m\n')
    print("Score :" ,score)
    print("Mean Score :",score.mean())
    print("Std deviation :",score.std())
    print('\n')
    print('------------------------------------------------------------------------------------------------------------------')
# Out:
# Cross Validation Score LogisticRegression() :
#
# Score : [0.59797297 0.70945946 0.80743243 0.83445946 0.84121622]
# Mean Score : 0.7581081081081081
# Std deviation : 0.09292935809164428
#
#
# ------------------------------------------------------------------------------------------------------------------
#
#
# Cross Validation Score SVC() :
#
# Score : [0.57094595 0.73648649 0.88513514 0.90878378 0.91891892]
# Mean Score : 0.8040540540540541
# Std deviation : 0.13389634904036926
#
#
# ------------------------------------------------------------------------------------------------------------------
#
#
# Cross Validation Score GaussianNB() :
#
# Score : [0.59797297 0.69256757 0.85472973 0.86824324 0.87162162]
# Mean Score : 0.777027027027027
# Std deviation : 0.11180339887498945
#
#
# ------------------------------------------------------------------------------------------------------------------
#
#
# Cross Validation Score DecisionTreeClassifier() :
#
# Score : [0.60135135 0.65202703 0.73310811 0.75337838 0.75675676]
# Mean Score : 0.6993243243243243
# Std deviation : 0.061963548746542606
#
#
# ------------------------------------------------------------------------------------------------------------------
#
#
# Cross Validation Score KNeighborsClassifier(n_neighbors=3) :
#
# Score : [0.67905405 0.69256757 0.76689189 0.77702703 0.76351351]
# Mean Score : 0.7358108108108108
# Std deviation : 0.041288151668789685
#
#
# ------------------------------------------------------------------------------------------------------------------
#
#
# Cross Validation Score RandomForestClassifier() :
#
# Score : [0.60810811 0.72635135 0.87837838 0.88851351 0.90540541]
# Mean Score : 0.8013513513513514
# Std deviation : 0.11603930595247171
#
#
# ------------------------------------------------------------------------------------------------------------------
#
#
# Cross Validation Score ExtraTreesClassifier() :
#
# Score : [0.6722973  0.79391892 0.91554054 0.91216216 0.91216216]
# Mean Score : 0.8412162162162163
# Std deviation : 0.09629267384278282
#
#
# ------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# <b>Hyper Parameter Tuning : GridSearchCV<b>

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter= {'criterion' : ['gini', 'entropy'],
             'max_features':['auto','sqrt','log2'],
              'min_samples_split':[3,5,8,11],
              'max_depth' : [10,20,30],
              'n_estimators' : [100,200,300,400]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),parameter,verbose=10)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# [CV 1/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 1/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.822 total time=   0.1s
# [CV 2/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 2/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.821 total time=   0.1s
# [CV 3/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 3/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.787 total time=   0.0s
# [CV 4/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 4/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 5/5; 1/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100
# [CV 5/5; 1/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=100;, score=0.816 total time=   0.2s
# [CV 1/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 1/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.812 total time=   0.2s
# [CV 2/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 2/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.845 total time=   0.2s
# [CV 3/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 3/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.787 total time=   0.2s
# [CV 4/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 4/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.754 total time=   0.2s
# [CV 5/5; 2/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200
# [CV 5/5; 2/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=200;, score=0.812 total time=   0.2s
# [CV 1/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 1/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.822 total time=   0.3s
# [CV 2/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 2/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.841 total time=   0.5s
# [CV 3/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 3/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.792 total time=   1.0s
# [CV 4/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 4/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.768 total time=   0.5s
# [CV 5/5; 3/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300
# [CV 5/5; 3/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=300;, score=0.816 total time=   0.3s
# [CV 1/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 1/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.822 total time=   0.5s
# [CV 2/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 2/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.845 total time=   0.5s
# [CV 3/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 3/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.797 total time=   0.4s
# [CV 4/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 4/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.787 total time=   0.4s
# [CV 5/5; 4/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400
# [CV 5/5; 4/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=3, n_estimators=400;, score=0.812 total time=   0.6s
# [CV 1/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 1/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.822 total time=   0.1s
# [CV 2/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 2/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.836 total time=   0.1s
# [CV 3/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 3/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.778 total time=   0.0s
# [CV 4/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 4/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.778 total time=   0.1s
# [CV 5/5; 5/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100
# [CV 5/5; 5/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=100;, score=0.812 total time=   0.0s
# [CV 1/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 1/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.817 total time=   0.3s
# [CV 2/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 2/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.826 total time=   0.2s
# [CV 3/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 3/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.802 total time=   0.2s
# [CV 4/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 4/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.792 total time=   0.2s
# [CV 5/5; 6/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200
# [CV 5/5; 6/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200;, score=0.826 total time=   0.3s
# [CV 1/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 1/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.846 total time=   0.3s
# [CV 2/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 2/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.831 total time=   0.5s
# [CV 3/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 3/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.802 total time=   0.3s
# [CV 4/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 4/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.768 total time=   0.3s
# [CV 5/5; 7/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300
# [CV 5/5; 7/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300;, score=0.812 total time=   0.3s
# [CV 1/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 1/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.822 total time=   0.5s
# [CV 2/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 2/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.831 total time=   0.7s
# [CV 3/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 3/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.783 total time=   0.5s
# [CV 4/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 4/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.778 total time=   0.6s
# [CV 5/5; 8/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400
# [CV 5/5; 8/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=5, n_estimators=400;, score=0.792 total time=   0.6s
# [CV 1/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 1/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.827 total time=   0.0s
# [CV 2/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 2/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.826 total time=   0.0s
# [CV 3/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 3/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.768 total time=   0.0s
# [CV 4/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 4/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.754 total time=   0.1s
# [CV 5/5; 9/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100
# [CV 5/5; 9/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=100;, score=0.792 total time=   0.0s
# [CV 1/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 1/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.827 total time=   0.2s
# [CV 2/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 2/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.826 total time=   0.2s
# [CV 3/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 3/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.797 total time=   0.2s
# [CV 4/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 4/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.749 total time=   0.2s
# [CV 5/5; 10/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200
# [CV 5/5; 10/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=200;, score=0.812 total time=   0.2s
# [CV 1/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 1/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.808 total time=   0.3s
# [CV 2/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 2/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.836 total time=   0.3s
# [CV 3/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 3/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.797 total time=   0.3s
# [CV 4/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 4/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.768 total time=   0.3s
# [CV 5/5; 11/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300
# [CV 5/5; 11/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=300;, score=0.812 total time=   0.5s
# [CV 1/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 1/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.827 total time=   0.4s
# [CV 2/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 2/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.836 total time=   0.4s
# [CV 3/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 3/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.773 total time=   0.5s
# [CV 4/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 4/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.778 total time=   0.4s
# [CV 5/5; 12/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400
# [CV 5/5; 12/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=8, n_estimators=400;, score=0.802 total time=   0.5s
# [CV 1/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 1/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.817 total time=   0.0s
# [CV 2/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 2/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.807 total time=   0.1s
# [CV 3/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 3/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 4/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 4/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.744 total time=   0.1s
# [CV 5/5; 13/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100
# [CV 5/5; 13/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=100;, score=0.797 total time=   0.0s
# [CV 1/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 1/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.812 total time=   0.3s
# [CV 2/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 2/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.816 total time=   0.2s
# [CV 3/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 3/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.792 total time=   0.2s
# [CV 4/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 4/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.778 total time=   0.2s
# [CV 5/5; 14/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200
# [CV 5/5; 14/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=200;, score=0.797 total time=   0.2s
# [CV 1/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 1/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.812 total time=   0.3s
# [CV 2/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 2/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.826 total time=   0.5s
# [CV 3/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 3/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.783 total time=   0.4s
# [CV 4/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 4/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.763 total time=   0.3s
# [CV 5/5; 15/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300
# [CV 5/5; 15/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=300;, score=0.816 total time=   0.3s
# [CV 1/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 1/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.812 total time=   0.4s
# [CV 2/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 2/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.836 total time=   0.4s
# [CV 3/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 3/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.783 total time=   0.4s
# [CV 4/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 4/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.773 total time=   0.5s
# [CV 5/5; 16/288] START criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400
# [CV 5/5; 16/288] END criterion=gini, max_depth=10, max_features=auto, min_samples_split=11, n_estimators=400;, score=0.807 total time=   0.5s
# [CV 1/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 1/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.827 total time=   0.0s
# [CV 2/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 2/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 3/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 3/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.797 total time=   0.1s
# [CV 4/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 4/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.792 total time=   0.1s
# [CV 5/5; 17/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100
# [CV 5/5; 17/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=100;, score=0.807 total time=   0.0s
# [CV 1/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 1/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.832 total time=   0.2s
# [CV 2/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 2/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.831 total time=   0.2s
# [CV 3/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 3/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.792 total time=   0.2s
# [CV 4/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 4/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.773 total time=   0.2s
# [CV 5/5; 18/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200
# [CV 5/5; 18/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=200;, score=0.812 total time=   0.2s
# [CV 1/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 1/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.832 total time=   0.3s
# [CV 2/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 2/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.821 total time=   0.5s
# [CV 3/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 3/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.778 total time=   0.4s
# [CV 4/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 4/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.763 total time=   0.3s
# [CV 5/5; 19/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300
# [CV 5/5; 19/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=300;, score=0.826 total time=   0.5s
# [CV 1/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 1/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.827 total time=   0.5s
# [CV 2/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 2/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.845 total time=   0.6s
# [CV 3/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 3/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.807 total time=   1.0s
# [CV 4/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 4/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.778 total time=   0.7s
# [CV 5/5; 20/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400
# [CV 5/5; 20/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=3, n_estimators=400;, score=0.831 total time=   0.5s
# [CV 1/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 1/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.837 total time=   0.0s
# [CV 2/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 2/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.821 total time=   0.1s
# [CV 3/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 3/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.763 total time=   0.0s
# [CV 4/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 4/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.778 total time=   0.0s
# [CV 5/5; 21/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100
# [CV 5/5; 21/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.826 total time=   0.1s
# [CV 1/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 1/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.832 total time=   0.3s
# [CV 2/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 2/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.821 total time=   0.2s
# [CV 3/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 3/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.797 total time=   0.1s
# [CV 4/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 4/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.758 total time=   0.1s
# [CV 5/5; 22/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200
# [CV 5/5; 22/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.816 total time=   0.2s
# [CV 1/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 1/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.827 total time=   0.5s
# [CV 2/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 2/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.836 total time=   0.4s
# [CV 3/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 3/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.792 total time=   0.3s
# [CV 4/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 4/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.792 total time=   0.3s
# [CV 5/5; 23/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300
# [CV 5/5; 23/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.802 total time=   0.3s
# [CV 1/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 1/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.846 total time=   0.4s
# [CV 2/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 2/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.826 total time=   0.4s
# [CV 3/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 3/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.797 total time=   0.6s
# [CV 4/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 4/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.768 total time=   0.5s
# [CV 5/5; 24/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400
# [CV 5/5; 24/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=400;, score=0.816 total time=   0.4s
# [CV 1/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 1/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.822 total time=   0.0s
# [CV 2/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 2/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.812 total time=   0.0s
# [CV 3/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 3/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.763 total time=   0.0s
# [CV 4/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 4/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.734 total time=   0.0s
# [CV 5/5; 25/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100
# [CV 5/5; 25/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=100;, score=0.812 total time=   0.0s
# [CV 1/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 1/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.832 total time=   0.2s
# [CV 2/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 2/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.821 total time=   0.2s
# [CV 3/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 3/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.778 total time=   0.2s
# [CV 4/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 4/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.768 total time=   0.1s
# [CV 5/5; 26/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200
# [CV 5/5; 26/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=200;, score=0.812 total time=   0.2s
# [CV 1/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 1/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.817 total time=   0.3s
# [CV 2/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 2/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.831 total time=   0.3s
# [CV 3/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 3/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.797 total time=   0.5s
# [CV 4/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 4/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.768 total time=   0.3s
# [CV 5/5; 27/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300
# [CV 5/5; 27/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=300;, score=0.821 total time=   0.3s
# [CV 1/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 1/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.822 total time=   0.5s
# [CV 2/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 2/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.831 total time=   0.7s
# [CV 3/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 3/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.787 total time=   0.8s
# [CV 4/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 4/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.773 total time=   0.5s
# [CV 5/5; 28/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400
# [CV 5/5; 28/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=8, n_estimators=400;, score=0.802 total time=   0.4s
# [CV 1/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 1/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.812 total time=   0.0s
# [CV 2/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 2/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 3/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 3/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.758 total time=   0.1s
# [CV 4/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 4/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.749 total time=   0.1s
# [CV 5/5; 29/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100
# [CV 5/5; 29/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=100;, score=0.787 total time=   0.1s
# [CV 1/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 1/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.817 total time=   0.2s
# [CV 2/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 2/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.807 total time=   0.2s
# [CV 3/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 3/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.787 total time=   0.1s
# [CV 4/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 4/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.773 total time=   0.1s
# [CV 5/5; 30/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200
# [CV 5/5; 30/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=200;, score=0.797 total time=   0.2s
# [CV 1/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 1/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.812 total time=   0.3s
# [CV 2/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 2/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.826 total time=   0.3s
# [CV 3/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 3/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.797 total time=   0.3s
# [CV 4/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 4/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.744 total time=   0.5s
# [CV 5/5; 31/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300
# [CV 5/5; 31/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=300;, score=0.816 total time=   0.6s
# [CV 1/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 1/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.808 total time=   0.7s
# [CV 2/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 2/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.821 total time=   0.6s
# [CV 3/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 3/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.787 total time=   0.4s
# [CV 4/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 4/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.758 total time=   0.4s
# [CV 5/5; 32/288] START criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400
# [CV 5/5; 32/288] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_split=11, n_estimators=400;, score=0.807 total time=   0.4s
# [CV 1/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 1/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.837 total time=   0.0s
# [CV 2/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 2/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.821 total time=   0.0s
# [CV 3/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 3/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.792 total time=   0.0s
# [CV 4/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 4/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.768 total time=   0.0s
# [CV 5/5; 33/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100
# [CV 5/5; 33/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=100;, score=0.792 total time=   0.0s
# [CV 1/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 1/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.822 total time=   0.2s
# [CV 2/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 2/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.831 total time=   0.2s
# [CV 3/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 3/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.792 total time=   0.2s
# [CV 4/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 4/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.783 total time=   0.2s
# [CV 5/5; 34/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200
# [CV 5/5; 34/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=200;, score=0.807 total time=   0.2s
# [CV 1/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 1/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.832 total time=   0.3s
# [CV 2/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 2/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.836 total time=   0.3s
# [CV 3/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 3/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.802 total time=   0.3s
# [CV 4/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 4/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.787 total time=   0.3s
# [CV 5/5; 35/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300
# [CV 5/5; 35/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=300;, score=0.802 total time=   0.3s
# [CV 1/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 1/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.846 total time=   0.5s
# [CV 2/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 2/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.826 total time=   0.4s
# [CV 3/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 3/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.792 total time=   0.4s
# [CV 4/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 4/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.787 total time=   0.4s
# [CV 5/5; 36/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400
# [CV 5/5; 36/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=3, n_estimators=400;, score=0.821 total time=   0.4s
# [CV 1/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.832 total time=   0.0s
# [CV 2/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.812 total time=   0.0s
# [CV 3/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.797 total time=   0.0s
# [CV 4/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.792 total time=   0.0s
# [CV 5/5; 37/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 37/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.783 total time=   0.0s
# [CV 1/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.832 total time=   0.1s
# [CV 2/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.831 total time=   0.1s
# [CV 3/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.787 total time=   0.2s
# [CV 4/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.758 total time=   0.1s
# [CV 5/5; 38/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 38/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.836 total time=   0.1s
# [CV 1/5; 39/288] START criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 39/288] END criterion=gini, max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.832 total time=   0.3s
# ...
# [CV 1/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 1/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.846 total time=   0.0s
# [CV 2/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 2/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.831 total time=   0.0s
# [CV 3/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 3/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.802 total time=   0.0s
# [CV 4/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 4/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.802 total time=   0.0s
# [CV 5/5; 277/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100
# [CV 5/5; 277/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.816 total time=   0.0s
# [CV 1/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 1/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.865 total time=   0.1s
# [CV 2/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 2/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.831 total time=   0.1s
# [CV 3/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 3/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.807 total time=   0.1s
# [CV 4/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 4/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.763 total time=   0.1s
# [CV 5/5; 278/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200
# [CV 5/5; 278/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.826 total time=   0.1s
# [CV 1/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 1/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.865 total time=   0.2s
# [CV 2/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 2/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.850 total time=   0.2s
# [CV 3/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 3/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.807 total time=   0.2s
# [CV 4/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 4/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.783 total time=   0.2s
# [CV 5/5; 279/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300
# [CV 5/5; 279/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.826 total time=   0.2s
# [CV 1/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 1/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.861 total time=   0.3s
# [CV 2/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 2/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.845 total time=   0.3s
# [CV 3/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 3/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.812 total time=   0.3s
# [CV 4/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 4/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.773 total time=   0.3s
# [CV 5/5; 280/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400
# [CV 5/5; 280/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=5, n_estimators=400;, score=0.826 total time=   0.3s
# [CV 1/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 1/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.856 total time=   0.0s
# [CV 2/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 2/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.826 total time=   0.0s
# [CV 3/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 3/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.807 total time=   0.0s
# [CV 4/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 4/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.763 total time=   0.0s
# [CV 5/5; 281/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100
# [CV 5/5; 281/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=100;, score=0.802 total time=   0.0s
# [CV 1/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 1/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.861 total time=   0.1s
# [CV 2/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 2/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.836 total time=   0.1s
# [CV 3/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 3/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.802 total time=   0.1s
# [CV 4/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 4/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.758 total time=   0.1s
# [CV 5/5; 282/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200
# [CV 5/5; 282/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=200;, score=0.812 total time=   0.1s
# [CV 1/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 1/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.837 total time=   0.2s
# [CV 2/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 2/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.841 total time=   0.2s
# [CV 3/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 3/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.816 total time=   0.2s
# [CV 4/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 4/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.773 total time=   0.2s
# [CV 5/5; 283/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300
# [CV 5/5; 283/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=300;, score=0.816 total time=   0.2s
# [CV 1/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 1/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.841 total time=   0.3s
# [CV 2/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 2/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.836 total time=   0.3s
# [CV 3/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 3/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.831 total time=   0.3s
# [CV 4/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 4/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.778 total time=   0.3s
# [CV 5/5; 284/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400
# [CV 5/5; 284/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=8, n_estimators=400;, score=0.826 total time=   0.3s
# [CV 1/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 1/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.832 total time=   0.0s
# [CV 2/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 2/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.841 total time=   0.0s
# [CV 3/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 3/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.802 total time=   0.0s
# [CV 4/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 4/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.787 total time=   0.0s
# [CV 5/5; 285/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100
# [CV 5/5; 285/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=100;, score=0.812 total time=   0.0s
# [CV 1/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 1/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.837 total time=   0.1s
# [CV 2/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 2/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.836 total time=   0.1s
# [CV 3/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 3/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.816 total time=   0.1s
# [CV 4/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 4/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.787 total time=   0.1s
# [CV 5/5; 286/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200
# [CV 5/5; 286/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=200;, score=0.831 total time=   0.1s
# [CV 1/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 1/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.841 total time=   0.2s
# [CV 2/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 2/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.841 total time=   0.2s
# [CV 3/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 3/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.802 total time=   0.2s
# [CV 4/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 4/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.773 total time=   0.1s
# [CV 5/5; 287/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300
# [CV 5/5; 287/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=300;, score=0.807 total time=   0.1s
# [CV 1/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 1/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.837 total time=   0.2s
# [CV 2/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 2/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.812 total time=   0.2s
# [CV 3/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 3/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.802 total time=   0.2s
# [CV 4/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 4/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.773 total time=   0.2s
# [CV 5/5; 288/288] START criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400
# [CV 5/5; 288/288] END criterion=entropy, max_depth=30, max_features=log2, min_samples_split=11, n_estimators=400;, score=0.826 total time=   0.2s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': [3, 5, 8, 11],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 30,
#  'max_features': 'log2',
#  'min_samples_split': 3,
#  'n_estimators': 300}

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 300, max_depth=30 ,
                                 min_samples_split= 3, max_features= 'log2')
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.8671171171171171

# %%
# Lets plot confusion matrix for  FinalModel
Matrix = confusion_matrix(Y_test, y_pred)

x_labels = ["NO","YES"]
y_labels = ["NO","YES"]

fig , ax = plt.subplots(figsize=(5,5))
sns.heatmap(Matrix, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, 
            cmap="plasma", xticklabels = x_labels, yticklabels = y_labels)

plt.xlabel("Predicted Label",fontsize=14,fontweight='bold')
plt.ylabel("True Label",fontsize=14,fontweight='bold')
plt.title('Confusion Matrix for Final Model',fontsize=20,fontweight='bold')
plt.show()

# %% [markdown]
# <b>ROC-AUC Curve<b>

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
disp = plot_roc_curve(Final_mod,X_test,Y_test)   
plt.legend(prop={'size':11}, loc='lower right')
plt.title('AOC ROC Curve of Final Model',fontsize=20,fontweight='bold')
plt.show()
auc_score = roc_auc_score(Y_test, Final_mod.predict(X_test))
print('\033[1m'+'Auc Score :'+'\033[0m\n',auc_score)
# Out:
# Auc Score :
#  0.8695811603650586

# %% [markdown]
# <b>Saving Model<b>

# %%
import joblib
joblib.dump(Final_mod,'Insurance_claims_Final.pkl')
# Out:
# ['Insurance_claims_Final.pkl']

# %% [markdown]
# <b>Final Model Prediction<b>

# %%
# Prediction
prediction = Final_mod.predict(X_test)

# %%
Actual = np.array(Y_test)
df_Pred = pd.DataFrame()
df_Pred["Predicted Values"] = prediction
df_Pred["Actual Values"] = Actual
df_Pred.head()
# Out:
#    Predicted Values  Actual Values
# 0                 0              0
# 1                 1              0
# 2                 1              1
# 3                 1              1
# 4                 1              1
